# %%
import json
from collections import defaultdict, Counter
import matplotlib.pyplot as plt

from data_analysis.obo_parsing import name_to_id


def map_go_annotations_to_proteins(json_file):
    """
    Maps GO annotations to proteins from a JSON file.

    Parameters:
        json_file (str): Path to the JSON file containing protein data.

    Returns:
        dict: A dictionary mapping GO terms to lists of protein IDs.
    """
    # Load the JSON data
    with open(json_file, 'r') as f:
        data = json.load(f)

    # Dictionary to map GO terms to protein IDs
    go_to_proteins = defaultdict(list)

    # Iterate through the proteins in the data
    for protein in data:
        protein_id = protein.get("protein_id")
        protein_name = protein.get("protein_name")
        go_annotations = protein.get("go_annotations", [])
        
        # Map each GO term to the current protein ID
        for go_term in go_annotations:
            go_to_proteins[go_term].append(tuple({protein_id, protein_name}))

    return go_to_proteins
# Out:
# GO:0140930

# %%
import json
from collections import defaultdict, Counter
import matplotlib.pyplot as plt

def map_go_annotations_ids_only_to_proteins(json_file):
    """
    Maps GO annotations to proteins from a JSON file.

    Parameters:
        json_file (str): Path to the JSON file containing protein data.

    Returns:
        dict: A dictionary mapping GO terms to lists of protein IDs.
    """
    # Load the JSON data
    with open(json_file, 'r') as f:
        data = json.load(f)

    # Dictionary to map GO terms to protein IDs
    go_to_proteins = defaultdict(list)

    # Iterate through the proteins in the data
    for protein in data:
        protein_id = protein.get("protein_id")
        protein_name = protein.get("protein_name")
        go_annotations = protein.get("go_annotations", [])
        
        # Map each GO term to the current protein ID
        for go_term in go_annotations:
            go_to_proteins[go_term].append(tuple({protein_id, protein_name}))

    return go_to_proteins

def map_go_annotations_to_proteins_with_go_ids(json_file):
    """
    Maps GO annotations to proteins from a JSON file.

    Parameters:
        json_file (str): Path to the JSON file containing protein data.

    Returns:
        dict: A dictionary mapping GO terms to lists of protein IDs.
    """
    # Load the JSON data
    with open(json_file, 'r') as f:
        data = json.load(f)

    # Dictionary to map GO terms to protein IDs
    go_to_proteins = defaultdict(list)

    # Iterate through the proteins in the data
    for protein in data:
        protein_id = protein.get("protein_id")
        protein_name = protein.get("protein_name")
        go_annotations = protein.get("go_annotations_with_ids", [])
        
        # Map each GO term to the current protein ID
        for go_term in go_annotations:
            go_to_proteins[go_term].append(tuple({protein_id, protein_name}))

    return go_to_proteins

# %%
json_file = "./../raw_data/parsed_proteins.json"  # Replace with the path to your JSON file
go_to_proteins = map_go_annotations_to_proteins(json_file)

go_to_proteins
# Out:
# defaultdict(list,
#             {'F:aromatase activity': [('A0A087X1C5',
#                'Putative cytochrome P450 2D7'),
#               ('P04798', 'Cytochrome P450 1A1'),
#               ('P05177', 'Cytochrome P450 1A2'),
#               ('Cytochrome P450 2E1', 'P05181'),
#               ('P08684', 'Cytochrome P450 3A4'),
#               ('P10632', 'Cytochrome P450 2C8'),
#               ('Aromatase', 'P11511'),
#               ('P11712', 'Cytochrome P450 2C9'),
#               ('P13584', 'Cytochrome P450 4B1'),
#               ('Cytochrome P450 3A5', 'P20815'),
#               ('Cytochrome P450 2A7', 'P20853'),
#               ('Cytochrome P450 3A7', 'P24462'),
#               ('Cytochrome P450 2F1', 'P24903'),
#               ('Cytochrome P450 2C18', 'P33260'),
#               ('P33261', 'Cytochrome P450 2C19'),
#               ('Cytochrome P450 4F2', 'P78329'),
#               ('Cytochrome P450 4F8', 'P98187'),
#               ('Q02928', 'Cytochrome P450 4A11'),
#               ('Q08477', 'Cytochrome P450 4F3'),
#               ('Cytochrome P450 1B1', 'Q16678'),
#               ('Cytochrome P450 2A13', 'Q16696'),
#               ('Q6V0L0', 'Cytochrome P450 26C1'),
#               ('Q86W10', 'Cytochrome P450 4Z1'),
#               ('Q9HB55', 'Cytochrome P450 3A43'),
#               ('Cytochrome P450 4F11', 'Q9HBI6'),
#               ('Q9HCS2', 'Cytochrome P450 4F12')],
#              'F:heme binding': [('A0A087X1C5', 'Putative cytochrome P450 2D7'),
#               ('A1KZ92', 'Probable oxidoreductase PXDNL'),
#               ('O00264',
#                'Membrane-associated progesterone receptor component 1'),
#               ('O14521',
#                'Succinate dehydrogenase [ubiquinone] cytochrome b small subunit, mitochondrial'),
#               ('O14569', 'Transmembrane reductase CYB561D2'),
#               ('O14867', 'Transcription regulator protein BACH1'),
#               ('Membrane-associated progesterone receptor component 2',
#                'O15173'),
#               ('25-hydroxyvitamin D-1 alpha hydroxylase, mitochondrial',
#                'O15528'),
#               ('Cytochrome b5 type B', 'O43169'),
#               ('Cytochrome P450 26A1', 'O43174'),
#               ('O60674', 'Tyrosine-protein kinase JAK2'),
#               ('O75343', 'Guanylate cyclase soluble subunit beta-2'),
#               ('Cytochrome P450 7B1', 'O75881'),
#               ('O76061', 'Stanniocalcin-2'),
#               ('P00167', 'Cytochrome b5'),
#               ('P00395', 'Cytochrome c oxidase subunit 1'),
#               ('Hemoglobin subunit zeta', 'P02008'),
#               ('Hemoglobin subunit delta', 'P02042'),
#               ('P02100', 'Hemoglobin subunit epsilon'),
#               ('P02144', 'Myoglobin'),
#               ('P02760', 'Protein AMBP'),
#               ('P04040', 'Catalase'),
#               ('Histidine-rich glycoprotein', 'P04196'),
#               ('P04798', 'Cytochrome P450 1A1'),
#               ('P04839', 'Cytochrome b-245 heavy chain'),
#               ('P05093', 'Steroid 17-alpha-hydroxylase/17,20 lyase'),
#               ('P05108',
#                'Cholesterol side-chain cleavage enzyme, mitochondrial'),
#               ('P05164', 'Myeloperoxidase'),
#               ('P05177', 'Cytochrome P450 1A2'),
#               ('Cytochrome P450 2E1', 'P05181'),
#               ('Thyroid peroxidase', 'P07202'),
#               ('P08574', 'Cytochrome c1, heme protein, mitochondrial'),
#               ('P08684', 'Cytochrome P450 3A4'),
#               ('P08686', 'Steroid 21-hydroxylase'),
#               ('P09105', 'Hemoglobin subunit theta-1'),
#               ('P09601', 'Heme oxygenase 1'),
#               ('P10632', 'Cytochrome P450 2C8'),
#               ('Cytochrome P450 2D6', 'P10635'),
#               ('P11509', 'Cytochrome P450 2A6'),
#               ('Aromatase', 'P11511'),
#               ('P11678', 'Eosinophil peroxidase'),
#               ('P11712', 'Cytochrome P450 2C9'),
#               ('P12931', 'Proto-oncogene tyrosine-protein kinase Src'),
#               ('Cytochrome b-245 light chain', 'P13498'),
#               ('P13584', 'Cytochrome P450 4B1'),
#               ('Indoleamine 2,3-dioxygenase 1', 'P14902'),
#               ('P15538', 'Cytochrome P450 11B1, mitochondrial'),
#               ('P19099', 'Cytochrome P450 11B2, mitochondrial'),
#               ('P20393', 'Nuclear receptor subfamily 1 group D member 1'),
#               ('Cytochrome P450 2B6', 'P20813'),
#               ('Cytochrome P450 3A5', 'P20815'),
#               ('Cytochrome P450 2A7', 'P20853'),
#               ('Lactoperoxidase', 'P22079'),
#               ('P22680', 'Cytochrome P450 7A1'),
#               ('P22830', 'Ferrochelatase, mitochondrial'),
#               ('P23219', 'Prostaglandin G/H synthase 1'),
#               ('Cytochrome P450 3A7', 'P24462'),
#               ('Thromboxane-A synthase', 'P24557'),
#               ('Cytochrome P450 2F1', 'P24903'),
#               ('Nitric oxide synthase 3', 'P29474'),
#               ('Nitric oxide synthase 1', 'P29475'),
#               ('Heme oxygenase 2', 'P30519'),
#               ('Cytochrome P450 2C18', 'P33260'),
#               ('P33261', 'Cytochrome P450 2C19'),
#               ('Guanylate cyclase soluble subunit alpha-2', 'P33402'),
#               ('Nitric oxide synthase, inducible', 'P35228'),
#               ('P35354', 'Prostaglandin G/H synthase 2'),
#               ('P35520', 'Cystathionine beta-synthase'),
#               ('Tryptophan 2,3-dioxygenase', 'P48775'),
#               ('Cytochrome P450 2J2', 'P51589'),
#               ('Sulfite oxidase, mitochondrial', 'P51687'),
#               ('Holocytochrome c-type synthase', 'P53701'),
#               ('P68871', 'Hemoglobin subunit beta'),
#               ('Hemoglobin subunit gamma-1', 'P69891'),
#               ('P69892', 'Hemoglobin subunit gamma-2'),
#               ('P69905', 'Hemoglobin subunit alpha'),
#               ('Cytochrome P450 4F2', 'P78329'),
#               ('Cytochrome P450 4F8', 'P98187'),
#               ('Cytochrome c', 'P99999'),
#               ('Q02108', 'Guanylate cyclase soluble subunit alpha-1'),
#               ('Q02153', 'Guanylate cyclase soluble subunit beta-1'),
#               ('Sterol 26-hydroxylase, mitochondrial', 'Q02318'),
#               ('Q02928', 'Cytochrome P450 4A11'),
#               ('Q07973',
#                '1,25-dihydroxyvitamin D(3) 24-hydroxylase, mitochondrial'),
#               ('Q08477', 'Cytochrome P450 4F3'),
#               ('Prostacyclin synthase', 'Q16647'),
#               ('Cytochrome P450 1B1', 'Q16678'),
#               ('Cytochrome P450 2A13', 'Q16696'),
#               ('Q16850', 'Lanosterol 14-alpha demethylase'),
#               ('Q4G0S4', 'Cytochrome P450 27C1'),
#               ('Q5TCH4', 'Cytochrome P450 4A22'),
#               ('Metalloreductase STEAP3', 'Q658P3'),
#               ('Q687X5', 'Metalloreductase STEAP4'),
#               ('Q6NT55', 'Ultra-long-chain fatty acid omega-hydroxylase'),
#               ('Q6P1K1', 'Heme transporter HRG1'),
#               ('Q6V0L0', 'Cytochrome P450 26C1'),
#               ('Q6VVX0', 'Vitamin D 25-hydroxylase'),
#               ('Indoleamine 2,3-dioxygenase 2', 'Q6ZQW0'),
#               ('Cytochrome P450 4V2', 'Q6ZWL3'),
#               ('Heme A synthase COX15', 'Q7KZN9'),
#               ('Cytochrome b5 reductase 4', 'Q7L1T6'),
#               ('Fatty acid 2-hydroxylase', 'Q7L5A8'),
#               ('Q7Z449', 'Cytochrome P450 2U1'),
#               ('Q86W10', 'Cytochrome P450 4Z1'),
#               ('Q8N7X0', 'Androglobin'),
#               ('Probable transmembrane reductase CYB561D1', 'Q8N8Q1'),
#               ('Q8TAV3', 'Cytochrome P450 2W1'),
#               ('Cytoglobin', 'Q8WWM9'),
#               ('Peroxynitrite isomerase THAP4', 'Q8WY91'),
#               ('Microprocessor complex subunit DGCR8', 'Q8WYQ5'),
#               ('Peroxidasin homolog', 'Q92626'),
#               ('Q96PH1', 'NADPH oxidase 5'),
#               ('Cytochrome P450 2S1', 'Q96SQ9'),
#               ('Q99643',
#                'Succinate dehydrogenase cytochrome b560 subunit, mitochondrial'),
#               ('Eukaryotic translation initiation factor 2-alpha kinase 1',
#                'Q9BQI3'),
#               ('Q9H7Z7', 'Prostaglandin E synthase 2'),
#               ('Q9HB55', 'Cytochrome P450 3A43'),
#               ('Cytochrome P450 4F11', 'Q9HBI6'),
#               ('NADPH oxidase 3', 'Q9HBY0'),
#               ('Q9HCS2', 'Cytochrome P450 4F12'),
#               ('ATP-binding cassette sub-family B member 6', 'Q9NP58'),
#               ('Q9NPG2', 'Neuroglobin'),
#               ('NADPH oxidase 4', 'Q9NPH5'),
#               ('Cytochrome P450 26B1', 'Q9NR63'),
#               ('Q9NRD8', 'Dual oxidase 2'),
#               ('Dual oxidase 1', 'Q9NRD9'),
#               ('Q9NS40',
#                'Voltage-gated inwardly rectifying potassium channel KCNH7'),
#               ('Q9NYL5', '24-hydroxycholesterol 7-alpha-hydroxylase'),
#               ('Q9UHE8', 'STEAP1 protein'),
#               ('7-alpha-hydroxycholest-4-en-3-one 12-alpha-hydroxylase',
#                'Q9UNU6'),
#               ('Q9UPI3', 'Choline/ethanolamine transporter FLVCR2'),
#               ('Choline/ethanolamine transporter FLVCR1', 'Q9Y5Y0'),
#               ('Q9Y5Z4', 'Heme-binding protein 2'),
#               ('Cholesterol 24-hydroxylase', 'Q9Y6A2'),
#               ('Hemoglobin subunit mu', 'Q6B0K9'),
#               ('Cytochrome P450 4X1', 'Q8N118'),
#               ('Neuferricin', 'Q8WUJ1'),
#               ('Q9HA92',
#                'Radical S-adenosyl methionine domain-containing protein 1, mitochondrial'),
#               ('Heme-binding protein 1', 'Q9NRV9'),
#               ('Q6UW02', 'Cytochrome P450 20A1'),
#               ('Q8N1L4',
#                'Putative inactive cytochrome P450 family member 4Z2'),
#               ('Putative inactive cytochrome P450 2G1', 'Q6ZSU1')],
#              'F:iron ion binding': [('A0A087X1C5',
#                'Putative cytochrome P450 2D7'),
#               ('tRNA wybutosine-synthesizing protein 5', 'A2RUC4'),
#               ('O00469', 'Procollagen-lysine,2-oxoglutarate 5-dioxygenase 2'),
#               ('O00767', 'Stearoyl-CoA desaturase'),
#               ('Serine/threonine-protein phosphatase with EF-hands 1',
#                'O14829'),
#               ('Serine/threonine-protein phosphatase with EF-hands 2',
#                'O14830'),
#               ('Polyunsaturated fatty acid lipoxygenase ALOX15B', 'O15296'),
#               ('Prolyl 4-hydroxylase subunit alpha-2', 'O15460'),
#               ('25-hydroxyvitamin D-1 alpha hydroxylase, mitochondrial',
#                'O15528'),
#               ('Cytochrome P450 26A1', 'O43174'),
#               ('Multifunctional procollagen lysine hydroxylase and glycosyltransferase LH3',
#                'O60568'),
#               ('O75151', 'Lysine-specific demethylase PHF2'),
#               ('O75342', 'Arachidonate 12-lipoxygenase, 12R-type'),
#               ('O75845', 'Lathosterol oxidase'),
#               ('Cytochrome P450 7B1', 'O75881'),
#               ('O75936', 'Gamma-butyrobetaine dioxygenase'),
#               ('Persulfide dioxygenase ETHE1, mitochondrial', 'O95571'),
#               ('Cholesterol 25-hydroxylase', 'O95992'),
#               ('P00439', 'Phenylalanine-4-hydroxylase'),
#               ('Hemoglobin subunit zeta', 'P02008'),
#               ('Lactotransferrin', 'P02788'),
#               ('P02792', 'Ferritin light chain'),
#               ('P02794', 'Ferritin heavy chain'),
#               ('P04798', 'Cytochrome P450 1A1'),
#               ('P05093', 'Steroid 17-alpha-hydroxylase/17,20 lyase'),
#               ('P05108',
#                'Cholesterol side-chain cleavage enzyme, mitochondrial'),
#               ('P05177', 'Cytochrome P450 1A2'),
#               ('Cytochrome P450 2E1', 'P05181'),
#               ('P08582', 'Melanotransferrin'),
#               ('P08684', 'Cytochrome P450 3A4'),
#               ('P08686', 'Steroid 21-hydroxylase'),
#               ('P09105', 'Hemoglobin subunit theta-1'),
#               ('Polyunsaturated fatty acid 5-lipoxygenase', 'P09917'),
#               ('Adrenodoxin, mitochondrial', 'P10109'),
#               ('P10632', 'Cytochrome P450 2C8'),
#               ('Cytochrome P450 2D6', 'P10635'),
#               ('P11509', 'Cytochrome P450 2A6'),
#               ('Aromatase', 'P11511'),
#               ('P11712', 'Cytochrome P450 2C9'),
#               ('P13584', 'Cytochrome P450 4B1'),
#               ('P13674', 'Prolyl 4-hydroxylase subunit alpha-1'),
#               ('P15538', 'Cytochrome P450 11B1, mitochondrial'),
#               ('P16050', 'Polyunsaturated fatty acid lipoxygenase ALOX15'),
#               ('P17752', 'Tryptophan 5-hydroxylase 1'),
#               ('Polyunsaturated fatty acid lipoxygenase ALOX12', 'P18054'),
#               ('P19099', 'Cytochrome P450 11B2, mitochondrial'),
#               ('Cytochrome P450 2B6', 'P20813'),
#               ('Cytochrome P450 3A5', 'P20815'),
#               ('Cytochrome P450 2A7', 'P20853'),
#               ('P22680', 'Cytochrome P450 7A1'),
#               ('Cytochrome P450 3A7', 'P24462'),
#               ('Thromboxane-A synthase', 'P24557'),
#               ('Cytochrome P450 2F1', 'P24903'),
#               ('Calreticulin', 'P27797'),
#               ('Cytochrome P450 2C18', 'P33260'),
#               ('P33261', 'Cytochrome P450 2C19'),
#               ('Xanthine dehydrogenase/oxidase', 'P47989'),
#               ('Cytochrome P450 2J2', 'P51589'),
#               ('P61221', 'ATP-binding cassette sub-family E member 1'),
#               ('P62136',
#                'Serine/threonine-protein phosphatase PP1-alpha catalytic subunit'),
#               ('P69905', 'Hemoglobin subunit alpha'),
#               ('Cytochrome P450 4F2', 'P78329'),
#               ('P80188', 'Neutrophil gelatinase-associated lipocalin'),
#               ('Cytochrome P450 4F8', 'P98187'),
#               ('Sterol 26-hydroxylase, mitochondrial', 'Q02318'),
#               ('Procollagen-lysine,2-oxoglutarate 5-dioxygenase 1', 'Q02809'),
#               ('Q02928', 'Cytochrome P450 4A11'),
#               ('Aldehyde oxidase', 'Q06278'),
#               ('Q07973',
#                '1,25-dihydroxyvitamin D(3) 24-hydroxylase, mitochondrial'),
#               ('Q08477', 'Cytochrome P450 4F3'),
#               ('Methylsterol monooxygenase 1', 'Q15800'),
#               ('Prostacyclin synthase', 'Q16647'),
#               ('Cytochrome P450 1B1', 'Q16678'),
#               ('Cytochrome P450 2A13', 'Q16696'),
#               ('Q16850', 'Lanosterol 14-alpha demethylase'),
#               ('Prolyl 3-hydroxylase 1', 'Q32P28'),
#               ('Q4G0S4', 'Cytochrome P450 27C1'),
#               ('Q5TCH4', 'Cytochrome P450 4A22'),
#               ('Q6FI81', 'Anamorsin'),
#               ('Q6NT55', 'Ultra-long-chain fatty acid omega-hydroxylase'),
#               ('Bifunctional arginine demethylase and lysyl-hydroxylase JMJD6',
#                'Q6NYC1'),
#               ('Q6V0L0', 'Cytochrome P450 26C1'),
#               ('Q6VVX0', 'Vitamin D 25-hydroxylase'),
#               ('Lysine-specific demethylase 7A', 'Q6ZMT4'),
#               ('Q6ZNB7', 'Alkylglycerol monooxygenase'),
#               ('Cytochrome P450 4V2', 'Q6ZWL3'),
#               ('Fatty acid 2-hydroxylase', 'Q7L5A8'),
#               ('Q7Z449', 'Cytochrome P450 2U1'),
#               ('Prolyl 4-hydroxylase subunit alpha-3', 'Q7Z4N8'),
#               ('Iron-sulfur cluster assembly 2 homolog, mitochondrial',
#                'Q86U28'),
#               ('Q86W10', 'Cytochrome P450 4Z1'),
#               ('Prolyl 3-hydroxylase 2', 'Q8IVL5'),
#               ('Prolyl 3-hydroxylase 3', 'Q8IVL6'),
#               ('Q8IWU9', 'Tryptophan 5-hydroxylase 2'),
#               ('Ferritin, mitochondrial', 'Q8N4E7'),
#               ('Prolyl 3-hydroxylase OGFOD1', 'Q8N543'),
#               ('Q8NFU7', 'Methylcytosine dioxygenase TET1'),
#               ('Q8TAV3', 'Cytochrome P450 2W1'),
#               ('Cytoglobin', 'Q8WWM9'),
#               ('tRNA (carboxymethyluridine(34)-5-O)-methyltransferase ALKBH8',
#                'Q96BT7'),
#               ('Q96IV6', 'Fatty acid hydroxylase domain-containing protein 2'),
#               ('Cytochrome P450 2S1', 'Q96SQ9'),
#               ('Q96SZ5', '2-aminoethanethiol dioxygenase'),
#               ('Aconitate hydratase, mitochondrial', 'Q99798'),
#               ('Q9BU89', 'Deoxyhypusine hydroxylase'),
#               ('Q9BV57', 'Acireductone dioxygenase'),
#               ('Q9BYJ1', 'Hydroperoxide isomerase ALOXE3'),
#               ('Q9H1K1', 'Iron-sulfur cluster assembly enzyme ISCU'),
#               ('Q9H6W3', 'Ribosomal oxygenase 1'),
#               ('Q9HB55', 'Cytochrome P450 3A43'),
#               ('Cytochrome P450 4F11', 'Q9HBI6'),
#               ('Q9HCS2', 'Cytochrome P450 4F12'),
#               ('Cytochrome P450 26B1', 'Q9NR63'),
#               ('Q9NVH6', 'Trimethyllysine dioxygenase, mitochondrial'),
#               ('Q9NXG6', 'Transmembrane prolyl 4-hydroxylase'),
#               ('Q9NYL5', '24-hydroxycholesterol 7-alpha-hydroxylase'),
#               ('F-box/LRR-repeat protein 5', 'Q9UKA1'),
#               ('NFU1 iron-sulfur cluster scaffold homolog, mitochondrial',
#                'Q9UMS0'),
#               ('7-alpha-hydroxycholest-4-en-3-one 12-alpha-hydroxylase',
#                'Q9UNU6'),
#               ('Histone lysine demethylase PHF8', 'Q9UPP1'),
#               ('Q9Y4C1', 'Lysine-specific demethylase 3A'),
#               ('Cholesterol 24-hydroxylase', 'Q9Y6A2'),
#               ('2-oxoglutarate and iron-dependent oxygenase domain-containing protein 2',
#                'Q6N063'),
#               ('2-oxoglutarate and iron-dependent oxygenase domain-containing protein 3',
#                'Q6PK18'),
#               ('Cytochrome P450 4X1', 'Q8N118'),
#               ('Q6UW02', 'Cytochrome P450 20A1'),
#               ('Q8N1L4',
#                'Putative inactive cytochrome P450 family member 4Z2'),
#               ('Putative inactive cytochrome P450 2G1', 'Q6ZSU1')],
#              'F:oxidoreductase activity, acting on paired donors, with incorporation or reduction of molecular oxygen, reduced flavin or flavoprotein as one donor, and incorporation of one atom of oxygen': [('A0A087X1C5',
#                'Putative cytochrome P450 2D7'),
#               ('P05177', 'Cytochrome P450 1A2'),
#               ('Cytochrome P450 2E1', 'P05181'),
#               ('P10632', 'Cytochrome P450 2C8'),
#               ('Cytochrome P450 2D6', 'P10635'),
#               ('P11509', 'Cytochrome P450 2A6'),
#               ('Aromatase', 'P11511'),
#               ('P11712', 'Cytochrome P450 2C9'),
#               ('Cytochrome P450 2B6', 'P20813'),
#               ('Cytochrome P450 2A7', 'P20853'),
#               ('Cytochrome P450 2F1', 'P24903'),
#               ('Cytochrome P450 2C18', 'P33260'),
#               ('P33261', 'Cytochrome P450 2C19'),
#               ('Cytochrome P450 2J2', 'P51589'),
#               ('Cytochrome P450 1B1', 'Q16678'),
#               ('Cytochrome P450 2A13', 'Q16696'),
#               ('Q16850', 'Lanosterol 14-alpha demethylase'),
#               ('Q6VVX0', 'Vitamin D 25-hydroxylase'),
#               ('Q7Z449', 'Cytochrome P450 2U1'),
#               ('Q8TAV3', 'Cytochrome P450 2W1'),
#               ('Cytochrome P450 2S1', 'Q96SQ9'),
#               ('Ubiquinone biosynthesis monooxygenase COQ6, mitochondrial',
#                'Q9Y2Z9')],
#              'F:DNA binding': [('A0A0C5B5G6',
#                'Mitochondrial-derived peptide MOTS-c'),
#               ('Protein FAM170A', 'A1A519'),
#               ('A4GXA9', 'Probable crossover junction endonuclease EME2'),
#               ('A6NHR9',
#                'Structural maintenance of chromosomes flexible hinge domain-containing protein 1'),
#               ('POU class 2 homeobox associating factor 3', 'A8K830'),
#               ('A8MT69', 'Centromere protein X'),
#               ('B2RXF5', 'Zinc finger and BTB domain-containing protein 42'),
#               ('O00115', 'Deoxyribonuclease-2-alpha'),
#               ('Transcription initiation factor TFIID subunit 4', 'O00268'),
#               ('Regulatory factor X-associated protein', 'O00287'),
#               ('Basic helix-loop-helix ARNT-like protein 1', 'O00327'),
#               ('O00470', 'Homeobox protein Meis1'),
#               ('O00482', 'Nuclear receptor subfamily 5 group A member 2'),
#               ('Zinc finger protein 593', 'O00488'),
#               ('O00571', 'ATP-dependent RNA helicase DDX3X'),
#               ('O00712', 'Nuclear factor 1 B-type'),
#               ('O14497', 'AT-rich interactive domain-containing protein 1A'),
#               ('O14593', 'DNA-binding protein RFXANK'),
#               ('O14646', 'Chromodomain-helicase-DNA-binding protein 1'),
#               ('Chromodomain-helicase-DNA-binding protein 2', 'O14647'),
#               ('O14686', 'Histone-lysine N-methyltransferase 2D'),
#               ('Programmed cell death protein 5', 'O14737'),
#               ('O14746', 'Telomerase reverse transcriptase'),
#               ('Homeobox protein Meis2', 'O14770'),
#               ('DNA-directed RNA polymerase III subunit RPC1', 'O14802'),
#               ('Interferon regulatory factor 6', 'O14896'),
#               ('Heterogeneous nuclear ribonucleoprotein D-like', 'O14979'),
#               ('O14981', 'TATA-binding protein-associated factor 172'),
#               ('O15160',
#                'DNA-directed RNA polymerases I and III subunit RPAC1'),
#               ('Phospholipid scramblase 1', 'O15162'),
#               ('O15209', 'Zinc finger and BTB domain-containing protein 22'),
#               ('O15315', 'DNA repair protein RAD51 homolog 2'),
#               ('O15370', 'Transcription factor SOX-12'),
#               ('O15409', 'Forkhead box protein P2'),
#               ('O15457', 'MutS protein homolog 4'),
#               ('O15499', 'Homeobox protein goosecoid-2'),
#               ('Circadian locomoter output cycles protein kaput', 'O15516'),
#               ('ATP-dependent RNA helicase DDX3Y', 'O15523'),
#               ('O15527', 'N-glycosylase/DNA lyase'),
#               ('PHD finger protein 1', 'O43189'),
#               ('O43316', 'Paired box protein Pax-4'),
#               ('52 kDa repressor of the inhibitor of the protein kinase',
#                'O43422'),
#               ('T-box transcription factor TBX1', 'O43435'),
#               ('DNA repair protein RAD51 homolog 3', 'O43502'),
#               ('Forkhead box protein O3', 'O43524'),
#               ('DNA repair protein XRCC3', 'O43542'),
#               ('O43543', 'DNA repair protein XRCC2'),
#               ('O43670',
#                'BUB3-interacting and GLEBS motif-containing protein ZNF207'),
#               ('Cyclic AMP-responsive element-binding protein 3', 'O43889'),
#               ('O60216', 'Double-strand-break repair protein rad21 homolog'),
#               ('Transcription factor SOX-15', 'O60248'),
#               ('SWI/SNF-related matrix-associated actin-dependent regulator of chromatin subfamily A member 5',
#                'O60264'),
#               ('Zinc finger protein 292', 'O60281'),
#               ('O60356', 'Nuclear protein 1'),
#               ('O60479', 'Homeobox protein DLX-3'),
#               ('cAMP-responsive element-binding protein-like 2', 'O60519'),
#               ('Cyclin-T1', 'O60563'),
#               ('O60673', 'DNA polymerase zeta catalytic subunit'),
#               ('O60814', 'Histone H2B type 1-K'),
#               ('Polyglutamine-binding protein 1', 'O60828'),
#               ('P antigen family member 4', 'O60829'),
#               ('O60869', 'Endothelial differentiation-related factor 1'),
#               ('O60870', 'DNA/RNA-binding protein KIN17'),
#               ('DnaJ homolog subfamily B member 6', 'O75190'),
#               ('O75367', 'Core histone macro-H2A.1'),
#               ('O75446', 'Histone deacetylase complex subunit SAP30'),
#               ('Transcriptional adapter 2-alpha', 'O75478'),
#               ('O75531', 'Barrier-to-autointegration factor'),
#               ('O75564', 'Jerky protein homolog'),
#               ('Mediator of RNA polymerase II transcription subunit 6',
#                'O75586'),
#               ('O75603', 'Chorion-specific transcription factor GCMb'),
#               ('Death effector domain-containing protein', 'O75618'),
#               ('O75683', 'Surfeit locus protein 6'),
#               ('O75717', 'WD repeat and HMG-box DNA-binding protein 1'),
#               ('O75771', 'DNA repair protein RAD51 homolog 4'),
#               ('E3 SUMO-protein ligase PIAS2', 'O75928'),
#               ('DNA fragmentation factor subunit beta', 'O76075'),
#               ('O76080', 'AN1-type zinc finger protein 5'),
#               ('ATP-dependent DNA helicase Q5', 'O94762'),
#               ('O95159', 'Zinc finger protein-like 1'),
#               ('Luc7-like protein 3', 'O95232'),
#               ('O95239', 'Chromosome-associated kinesin KIF4A'),
#               ('Methyl-CpG-binding domain protein 4', 'O95243'),
#               ('O95361', 'Tripartite motif-containing protein 16'),
#               ('O95365', 'Zinc finger and BTB domain-containing protein 7A'),
#               ('O95409', 'Zinc finger protein ZIC 2'),
#               ('DNA-directed RNA polymerase I subunit RPA1', 'O95602'),
#               ('O95789', 'Zinc finger MYM-type protein 6'),
#               ('O95831', 'Apoptosis-inducing factor 1, mitochondrial'),
#               ('Eomesodermin homolog', 'O95936'),
#               ('T-box transcription factor TBX6', 'O95947'),
#               ('O95983', 'Methyl-CpG-binding domain protein 3'),
#               ('DNA topoisomerase 3-beta-1', 'O95985'),
#               ('P00519', 'Tyrosine-protein kinase ABL1'),
#               ('P01011', 'Alpha-1-antichymotrypsin'),
#               ('Myc proto-oncogene protein', 'P01106'),
#               ('P02768', 'Albumin'),
#               ('Lactotransferrin', 'P02788'),
#               ('Angiogenin', 'P03950'),
#               ('Antileukoproteinase', 'P03973'),
#               ('DNA nucleotidylexotransferase', 'P04053'),
#               ('P04179', 'Superoxide dismutase [Mn], mitochondrial'),
#               ('N-myc proto-oncogene protein', 'P04198'),
#               ('P04553', 'Sperm protamine P1'),
#               ('Protamine-2', 'P04554'),
#               ('P04637', 'Cellular tumor antigen p53'),
#               ('P04908', 'Histone H2A type 1-B/E'),
#               ('Amyloid-beta precursor protein', 'P05067'),
#               ('P05114', 'Non-histone chromosomal protein HMG-14'),
#               ('Transcription factor Jun', 'P05412'),
#               ('DNA-directed RNA polymerase III subunit RPC4', 'P05423'),
#               ('Transcription factor AP-2-alpha', 'P05549'),
#               ('P06401', 'Progesterone receptor'),
#               ('P06899', 'Histone H2B type 1-J'),
#               ('Major centromere autoantigen B', 'P07199'),
#               ('Transcription factor Sp1', 'P08047'),
#               ('Zinc finger protein GLI1', 'P08151'),
#               ('Small ribosomal subunit protein uS2', 'P08865'),
#               ('P09012', 'U1 small nuclear ribonucleoprotein A'),
#               ('Spermatid nuclear transition protein 1', 'P09430'),
#               ('P09651', 'Heterogeneous nuclear ribonucleoprotein A1'),
#               ('P09874', 'Poly [ADP-ribose] polymerase 1'),
#               ('DNA polymerase alpha catalytic subunit', 'P09884'),
#               ('TCF3 fusion partner', 'P0C1Z6'),
#               ('Ataxin-1-like', 'P0C7T5'),
#               ('Zinc finger protein 688', 'P0C7X2'),
#               ('DNA-directed RNA polymerases I and III subunit RPAC2',
#                'P0DPB6'),
#               ('Histone H3.X', 'P0DPK5'),
#               ('Acrosin', 'P10323'),
#               ('Microtubule-associated protein tau', 'P10636'),
#               ('Retinoic acid receptor beta', 'P10826'),
#               ('Thyroid hormone receptor beta', 'P10828'),
#               ('Interferon regulatory factor 1', 'P10914'),
#               ('Transcriptional regulator ERG', 'P11308'),
#               ('P11387', 'DNA topoisomerase 1'),
#               ('DNA topoisomerase 2-alpha', 'P11388'),
#               ('Vitamin D3 receptor', 'P11473'),
#               ("Inosine-5'-monophosphate dehydrogenase 2", 'P12268'),
#               ('P12524', 'Protein L-Myc'),
#               ('P12956', 'X-ray repair cross-complementing protein 6'),
#               ('Protein lyl-1', 'P12980'),
#               ('P13010', 'X-ray repair cross-complementing protein 5'),
#               ('Nuclear receptor subfamily 2 group C member 1', 'P13056'),
#               ('P13631', 'Retinoic acid receptor gamma'),
#               ('Zinc finger protein 35', 'P13682'),
#               ('P13984', 'General transcription factor IIF subunit 2'),
#               ('P14316', 'Interferon regulatory factor 2'),
#               ('P14373', 'Zinc finger protein RFP'),
#               ('Homeobox protein Hox-B1', 'P14653'),
#               ('P14859', 'POU domain, class 2, transcription factor 1'),
#               ('P14921', 'Protein C-ets-1'),
#               ('Protein C-ets-2', 'P15036'),
#               ('P15884', 'Transcription factor 4'),
#               ('V(D)J recombination-activating protein 1', 'P15918'),
#               ('P15923', 'Transcription factor E2-alpha'),
#               ('Erythroid transcription factor', 'P15976'),
#               ('Histone H2AX', 'P16104'),
#               ('Intron Large complex component GCFC2', 'P16383'),
#               ('Methylated-DNA--protein-cysteine methyltransferase', 'P16455'),
#               ('P17036', 'Zinc finger protein 3'),
#               ('P17096', 'High mobility group protein HMG-I/HMG-Y'),
#               ('Transcription factor JunB', 'P17275'),
#               ('P17676', 'CCAAT/enhancer-binding protein beta'),
#               ('P17861', 'X-box-binding protein 1'),
#               ('P18124', 'Large ribosomal subunit protein uL30'),
#               ('Early growth response protein 1', 'P18146'),
#               ('P18583', 'Protein SON'),
#               ('P18848', 'Cyclic AMP-dependent transcription factor ATF-4'),
#               ('DNA ligase 1', 'P18858'),
#               ('DNA-directed RNA polymerase II subunit RPB3', 'P19387'),
#               ('P19388',
#                'DNA-directed RNA polymerases I, II, and III subunit RPABC1'),
#               ('General transcription and DNA repair factor IIH helicase/translocase subunit XPB',
#                'P19447'),
#               ('P19474', 'E3 ubiquitin-protein ligase TRIM21'),
#               ('Complement receptor type 2', 'P20023'),
#               ('P20265', 'POU domain, class 3, transcription factor 2'),
#               ('Homeobox protein Hox-A5', 'P20719'),
#               ('Hepatocyte nuclear factor 1-alpha', 'P20823'),
#               ("Inosine-5'-monophosphate dehydrogenase 1", 'P20839'),
#               ('P21580', 'Tumor necrosis factor alpha-induced protein 3'),
#               ('Nucleoside diphosphate kinase B', 'P22392'),
#               ('Nuclear receptor subfamily 4immunitygroup A member 1',
#                'P22736'),
#               ('Transcription elongation factor A protein 1', 'P23193'),
#               ('Splicing factor, proline- and glutamine-rich', 'P23246'),
#               ('P23396', 'Small ribosomal subunit protein uS3'),
#               ('Nuclear autoantigen Sp-100', 'P23497'),
#               ('P23511', 'Nuclear transcription factor Y subunit alpha'),
#               ('P23527', 'Histone H2B type 1-O'),
#               ('Trans-acting T-cell-specific transcription factor GATA-3',
#                'P23771'),
#               ('P24855', 'Deoxyribonuclease-1'),
#               ('P24928', 'DNA-directed RNA polymerase II subunit RPB1'),
#               ('P25205', 'DNA replication licensing factor MCM3'),
#               ('Nuclear transcription factor Y subunit beta', 'P25208'),
#               ('Transcriptional repressor protein YY1', 'P25490'),
#               ('DNA (cytosine-5)-methyltransferase 1', 'P26358'),
#               ('Paired box protein Pax-6', 'P26367'),
#               ('P26583', 'High mobility group protein B2'),
#               ('mRNA decay activator protein ZFP36', 'P26651'),
#               ('DNA repair nuclease/redox regulator APEX1', 'P27695'),
#               ('Calreticulin', 'P27797'),
#               ('P28324', 'ETS domain-containing protein Elk-4'),
#               ('P28340', 'DNA polymerase delta catalytic subunit'),
#               ('Transcriptional enhancer factor TEF-1', 'P28347'),
#               ('Probable global transcription activator SNF2L1', 'P28370'),
#               ('Mitogen-activated protein kinase 1', 'P28482'),
#               ('Transcription initiation factor IIE subunit beta', 'P29084'),
#               ('P29374', 'AT-rich interactive domain-containing protein 4A'),
#               ('P29375', 'Lysine-specific demethylase 5A'),
#               ('Protein PML', 'P29590'),
#               ('P29692', 'Elongation factor 1-delta'),
#               ('P30876', 'DNA-directed RNA polymerase II subunit RPB2'),
#               ('P31271', 'Homeobox protein Hox-A13'),
#               ('Transcription factor HIVEP2', 'P31629'),
#               ('P33778', 'Histone H2B type 1-B'),
#               ('P35227', 'Polycomb group RING finger protein 2'),
#               ('Replication factor C subunit 4', 'P35249'),
#               ('P35250', 'Replication factor C subunit 2'),
#               ('Replication factor C subunit 1', 'P35251'),
#               ('General transcription factor IIF subunit 1', 'P35269'),
#               ('P35398', 'Nuclear receptor ROR-alpha'),
#               ('P35453', 'Homeobox protein Hox-D13'),
#               ('RNA-binding protein FUS', 'P35637'),
#               ('DNA damage-inducible transcript 3 protein', 'P35638'),
#               ('Protein DEK', 'P35659'),
#               ('Hepatocyte nuclear factor 1-beta', 'P35680'),
#               ('Transcription factor SOX-6', 'P35712'),
#               ('Aryl hydrocarbon receptor', 'P35869'),
#               ('P36956', 'Sterol regulatory element-binding protein 1'),
#               ('P37231', 'Peroxisome proliferator-activated receptor gamma'),
#               ('P38398', 'Breast cancer type 1 susceptibility protein'),
#               ('DNA-binding protein SMUBP-2', 'P38935'),
#               ('P39748', 'Flap endonuclease 1'),
#               ('Pre-B-cell leukemia transcription factor 1', 'P40424'),
#               ('P40763', 'Signal transducer and activator of transcription 3'),
#               ('P40937', 'Replication factor C subunit 5'),
#               ('Replication factor C subunit 3', 'P40938'),
#               ('P41159', 'Leptin'),
#               ('P41161', 'ETS translocation variant 5'),
#               ('Transcription factor SOX-3', 'P41225'),
#               ('P41229', 'Lysine-specific demethylase 5C'),
#               ('Hepatocyte nuclear factor 4-alpha', 'P41235'),
#               ('Lamina-associated polypeptide 2, isoform alpha', 'P42166'),
#               ('Lamina-associated polypeptide 2, isoforms beta/gamma',
#                'P42167'),
#               ('P42568', 'Protein AF-9'),
#               ('P42677', 'Small ribosomal subunit protein eS27'),
#               ('DNA mismatch repair protein Msh2', 'P43246'),
#               ('P43351', 'DNA repair protein RAD52 homolog'),
#               ('P43354', 'Nuclear receptor subfamily 4 group A member 2'),
#               ('Transcription factor GATA-4', 'P43694'),
#               ('P43699', 'Homeobox protein Nkx-2.1'),
#               ('Proliferation marker protein Ki-67', 'P46013'),
#               ('DNA-binding protein RFX2', 'P48378'),
#               ('P48380', 'Transcription factor RFX3'),
#               ('Transcription factor SOX-2', 'P48431'),
#               ('DNA polymerase delta subunit 2', 'P49005'),
#               ('P49184', 'Deoxyribonuclease-1-like 1'),
#               ('Histone H3-like centromeric protein A', 'P49450'),
#               ('P49643', 'DNA primase large subunit'),
#               ('P49715', 'CCAAT/enhancer-binding protein alpha'),
#               ('P49736', 'DNA replication licensing factor MCM2'),
#               ('P49790', 'Nuclear pore complex protein Nup153'),
#               ('P49848', 'Transcription initiation factor TFIID subunit 6'),
#               ('P49916', 'DNA ligase 3'),
#               ('P49917', 'DNA ligase 4'),
#               ('P50750', 'Cyclin-dependent kinase 9'),
#               ('DNA replication ATP-dependent helicase/nuclease DNA2',
#                'P51530'),
#               ('P51531', 'Probable global transcription activator SNF2L2'),
#               ('P51532', 'Transcription activator BRG1'),
#               ('Methyl-CpG-binding protein 2', 'P51608'),
#               ('Nuclear cap-binding protein subunit 2', 'P52298'),
#               ('DNA-directed RNA polymerase II subunit RPB11-a', 'P52435'),
#               ('Arf-GAP domain and FG repeat-containing protein 1', 'P52594'),
#               ('P52655', 'Transcription initiation factor IIA subunit 1'),
#               ('P52756', 'RNA-binding protein 5'),
#               ('P52952', 'Homeobox protein Nkx-2.5'),
#               ('Protein FosB', 'P53539'),
#               ('P53567', 'CCAAT/enhancer-binding protein gamma'),
#               ('P53803',
#                'DNA-directed RNA polymerases I, II, and III subunit RPABC4'),
#               ('P54098', 'DNA polymerase subunit gamma-1'),
#               ('P54132', 'RecQ-like DNA helicase BLM'),
#               ('P54253', 'Ataxin-1'),
#               ('Telomeric repeat-binding factor 1', 'P54274'),
#               ('P54277', 'PMS1 protein homolog 1'),
#               ('P54278', 'Mismatch repair endonuclease PMS2'),
#               ('Neural retina-specific leucine zipper protein', 'P54845'),
#               ('P55055', 'Oxysterols receptor LXR-beta'),
#               ('Protein AF-10', 'P55197'),
#               ('P55201', 'Peregrin'),
#               ('P55265', 'Double-stranded RNA-specific adenosine deaminase'),
#               ('P55316', 'Forkhead box protein G1'),
#               ('P55317', 'Hepatocyte nuclear factor 3-alpha'),
#               ('DNA polymerase epsilon subunit 2', 'P56282'),
#               ('P56693', 'Transcription factor SOX-10'),
#               ('Histone H2B type F-S', 'P57053'),
#               ('P57073', 'Transcription factor SOX-8'),
#               ('P57082', 'T-box transcription factor TBX4'),
#               ('P58012', 'Forkhead box protein L2'),
#               ('P58340', 'Myeloid leukemia factor 1'),
#               ('Histone H2B type 1-D', 'P58876'),
#               ('P61218',
#                'DNA-directed RNA polymerases I, II, and III subunit RPABC2'),
#               ('Protein max', 'P61244'),
#               ('Heterogeneous nuclear ribonucleoprotein K', 'P61978'),
#               ('Histone H4', 'P62805'),
#               ('P62807', 'Histone H2B type 1-C/E/F/G/I'),
#               ('Small ribosomal subunit protein uS19', 'P62841'),
#               ('P62875',
#                'DNA-directed RNA polymerases I, II, and III subunit RPABC5'),
#               ('P67809', 'Y-box-binding protein 1'),
#               ('P68431', 'Histone H3.1'),
#               ('P78317', 'E3 ubiquitin-protein ligase RNF4'),
#               ('P78332', 'RNA-binding protein 6'),
#               ('P78347', 'General transcription factor II-I'),
#               ('P78364', 'Polyhomeotic-like protein 1'),
#               ('P80303', 'Nucleobindin-2'),
#               ('P82094', 'TATA element modulatory factor'),
#               ('P82979', 'SAP domain-containing ribonucleoprotein'),
#               ('P84022', 'Mothers against decapentaplegic homolog 3'),
#               ('P98177', 'Forkhead box protein O4'),
#               ('Q00613', 'Heat shock factor protein 1'),
#               ('Heterogeneous nuclear ribonucleoprotein U', 'Q00839'),
#               ('Q01085', 'Nucleolysin TIAR'),
#               ('Q01094', 'Transcription factor E2F1'),
#               ('Q01105', 'Protein SET'),
#               ('Q01196', 'Runt-related transcription factor 1'),
#               ('Myelin transcription factor 1', 'Q01538'),
#               ('Friend leukemia integration 1 transcription factor', 'Q01543'),
#               ('Q01658', 'Protein Dr1'),
#               ('Q01664', 'Transcription factor AP-4'),
#               ('POU domain, class 5, transcription factor 1', 'Q01860'),
#               ('Q02818', 'Nucleobindin-1'),
#               ('Q02878', 'Large ribosomal subunit protein eL6'),
#               ('DNA topoisomerase 2-beta', 'Q02880'),
#               ('Q02962', 'Paired box protein Pax-2'),
#               ('cAMP-responsive element modulator', 'Q03060'),
#               ('Histone-lysine N-methyltransferase MECOM', 'Q03112'),
#               ('Q03181', 'Peroxisome proliferator-activated receptor delta'),
#               ('Centromere protein C', 'Q03188'),
#               ('Q03468', 'DNA excision repair protein ERCC-6'),
#               ('Q03989', 'AT-rich interactive domain-containing protein 5A'),
#               ('Transcription factor p65', 'Q04206'),
#               ('Sex-determining region Y protein', 'Q05066'),
#               ('Zinc finger and BTB domain-containing protein 16', 'Q05516'),
#               ('Recombining binding protein suppressor of hairless', 'Q06330'),
#               ('Myocyte-specific enhancer factor 2C', 'Q06413'),
#               ('Q06455', 'Protein CBFA2T1'),
#               ('Q06481', 'Amyloid beta precursor like protein 2'),
#               ('Q06710', 'Paired box protein Pax-8'),
#               ('Q07352', 'mRNA decay activator protein ZFP36L1'),
#               ('Q07666',
#                'KH domain-containing, RNA-binding, signal transduction-associated protein 1'),
#               ('Q07864', 'DNA polymerase epsilon catalytic subunit A'),
#               ('Peroxisome proliferator-activated receptor alpha', 'Q07869'),
#               ('Q08050', 'Forkhead box protein M1'),
#               ('Q08211', 'ATP-dependent RNA helicase A'),
#               ('Q08945', 'FACT complex subunit SSRP1'),
#               ('Q09472', 'Histone acetyltransferase p300'),
#               ('Q0VG06', 'Fanconi anemia core complex-associated protein 100'),
#               ('General transcription factor 3C polypeptide 1', 'Q12789'),
#               ('Alpha-globin transcription factor CP2', 'Q12800'),
#               ('Q12824',
#                'SWI/SNF-related matrix-associated actin-dependent regulator of chromatin subfamily B member 1'),
#               ('Chromodomain-helicase-DNA-binding protein 3', 'Q12873'),
#               ('Q12899', 'Tripartite motif-containing protein 26'),
#               ('Q12905', 'Interleukin enhancer-binding factor 2'),
#               ('Interleukin enhancer-binding factor 3', 'Q12906'),
#               ('Q12946', 'Forkhead box protein F1'),
#               ('Q12947', 'Forkhead box protein F2'),
#               ('Forkhead box protein C1', 'Q12948'),
#               ('Q12952', 'Forkhead box protein L1'),
#               ('Transcription initiation factor TFIID subunit 10', 'Q12962'),
#               ('Nuclear inhibitor of protein phosphatase 1', 'Q12972'),
#               ('Zinc finger protein Rlf', 'Q13129'),
#               ('Q13133', 'Oxysterols receptor LXR-alpha'),
#               ('TAR DNA-binding protein 43', 'Q13148'),
#               ('Q13207', 'T-box transcription factor TBX2'),
#               ('Q13263', 'Transcription intermediary factor 1-beta'),
#               ('Ras GTPase-activating protein-binding protein 1', 'Q13283'),
#               ('Q13285', 'Steroidogenic factor 1'),
#               ('Serine-protein kinase ATM', 'Q13315'),
#               ('Q13342', 'Nuclear body protein SP140'),
#               ('Q13415', 'Origin recognition complex subunit 1'),
#               ('Q13422', 'DNA-binding protein Ikaros'),
#               ('Q13461', 'Forkhead box protein E3'),
#               ('Q13469', 'Nuclear factor of activated T-cells, cytoplasmic 2'),
#               ('Q13472', 'DNA topoisomerase 3-alpha'),
#               ('Q13535', 'Serine/threonine-protein kinase ATR'),
#               ('G/T mismatch-specific thymine DNA glycosylase', 'Q13569'),
#               ('Deoxyribonuclease gamma', 'Q13609'),
#               ('Q13765',
#                'Nascent polypeptide-associated complex subunit alpha'),
#               ('Plakophilin-1', 'Q13835'),
#               ('Q13901', 'Nuclear nucleic acid-binding protein C1D'),
#               ('Q13952', 'Nuclear transcription factor Y subunit gamma'),
#               ('Q14149', 'MORC family CW-type zinc finger protein 3'),
#               ('Q14181', 'DNA polymerase alpha subunit B'),
#               ('Transcription factor Dp-2', 'Q14188'),
#               ('Q14190', 'Single-minded homolog 2'),
#               ('Q14191',
#                "Bifunctional 3'-5' exonuclease/ATP-dependent helicase WRN"),
#               ('Zinc finger MYM-type protein 3', 'Q14202'),
#               ('Q14209', 'Transcription factor E2F2'),
#               ('Transcription factor HES-1', 'Q14469'),
#               ('Q14527', 'Helicase-like transcription factor'),
#               ('Q14565', 'Meiotic recombination protein DMC1/LIM15 homolog'),
#               ('Q14587', 'Zinc finger protein 268'),
#               ('Interferon regulatory factor 3', 'Q14653'),
#               ('Q14683', 'Structural maintenance of chromosomes protein 1A'),
#               ('Delta(14)-sterol reductase LBR', 'Q14739'),
#               ('Q14781', 'Chromobox protein homolog 2'),
#               ('Kinesin-like protein KIF22', 'Q14807'),
#               ('Q14839', 'Chromodomain-helicase-DNA-binding protein 4'),
#               ('AT-rich interactive domain-containing protein 5B', 'Q14865'),
#               ('Q14872', 'Metal regulatory transcription factor 1'),
#               ('E3 ubiquitin-protein ligase SHPRH', 'Q149N8'),
#               ('Histone-lysine N-methyltransferase SETDB1', 'Q15047'),
#               ('Zinc finger protein OZF', 'Q15072'),
#               ('Q15233', 'Non-POU domain-containing octamer-binding protein'),
#               ('Q15327', 'Ankyrin repeat domain-containing protein 1'),
#               ('Q15361', 'Transcription termination factor 1'),
#               ('Pumilio homolog 3', 'Q15397'),
#               ('Nuclear receptor subfamily 6 group A member 1', 'Q15406'),
#               ('Synaptonemal complex protein 1', 'Q15431'),
#               ('Q15475', 'Homeobox protein SIX1'),
#               ('Transcription initiation factor TFIID subunit 13', 'Q15543'),
#               ('Transcription elongation factor A protein 2', 'Q15560'),
#               ('Q15573',
#                'TATA box-binding protein-associated factor RNA polymerase I subunit A'),
#               ('Translin', 'Q15631'),
#               ("2'-5'-oligoadenylate synthase-like protein", 'Q15646'),
#               ('Vacuolar protein sorting-associated protein 72 homolog',
#                'Q15906'),
#               ('Zinc finger and BTB domain-containing protein 6', 'Q15916'),
#               ('Q15973', 'Zinc finger protein 124'),
#               ('Nuclear factor erythroid 2-related factor 2', 'Q16236'),
#               ('Transcription factor E2F4', 'Q16254'),
#               ('Q16342', 'Programmed cell death protein 2'),
#               ('Q16514', 'Transcription initiation factor TFIID subunit 12'),
#               ('Cryptochrome-1', 'Q16526'),
#               ('Q16531', 'DNA damage-binding protein 1'),
#               ('Hepatic leukemia factor', 'Q16534'),
#               ('Transcription initiation factor TFIID subunit 9', 'Q16594'),
#               ('Zinc finger protein 239', 'Q16600'),
#               ('Transcription factor NF-E2 45 kDa subunit', 'Q16621'),
#               ('Q16633', 'POU domain class 2-associating factor 1'),
#               ('Forkhead box protein D1', 'Q16676'),
#               ('Q16695', 'Histone H3.1t'),
#               ('Histone H2B type 2-E', 'Q16778'),
#               ('Q17R98', 'Zinc finger protein 827'),
#               ('Q2NKX8', 'DNA excision repair protein ERCC-6-like'),
#               ('Q2TAL8', 'Transcriptional regulator QRICH1'),
#               ('Chromosome-associated kinesin KIF4B', 'Q2VIQ3'),
#               ('Leucine-rich repeat flightless-interacting protein 1',
#                'Q32MZ4'),
#               ('Membrane-anchored junction protein', 'Q3KP22'),
#               ('Chromodomain-helicase-DNA-binding protein 9', 'Q3L8U1'),
#               ('Q49A26', 'Cytokine-like nuclear factor N-PAC'),
#               ('Transcription termination factor 2, mitochondrial', 'Q49AM1'),
#               ('Q49AN0', 'Cryptochrome-2'),
#               ('AT-rich interactive domain-containing protein 4B', 'Q4LE39'),
#               ('Q4VC44', 'FLYWCH-type zinc finger-containing protein 1'),
#               ('Histone-lysine N-methyltransferase SETMAR', 'Q53H47'),
#               ('Q53HV7',
#                'Single-strand selective monofunctional uracil DNA glycosylase'),
#               ('Q5BKZ1', 'DBIRD complex subunit ZNF326'),
#               ('Endoribonuclease ZC3H12A', 'Q5D1E8'),
#               ('Centromere protein W', 'Q5EE01'),
#               ('Transcription factor Dp family member 3', 'Q5H9I0'),
#               ('Q5JUK2',
#                'Spermatogenesis- and oogenesis-specific basic helix-loop-helix-containing protein 1'),
# ...
#               ('O95149', 'Snurportin-1'),
#               ('P06730', 'Eukaryotic translation initiation factor 4E'),
#               ('Nuclear cap-binding protein subunit 2', 'P52298'),
#               ('Eukaryotic initiation factor 4A-I', 'P60842'),
#               ('Nuclear cap-binding protein subunit 1', 'Q09161'),
#               ('Q13325',
#                'Interferon-induced protein with tetratricopeptide repeats 5'),
#               ('Nuclear cap-binding protein subunit 3', 'Q53F19'),
#               ('Q659C4', 'La-related protein 1B'),
#               ('La-related protein 1', 'Q6PKG0'),
#               ('Q9ULC4', 'Malignant T-cell-amplified sequence 1'),
#               ('Nuclear cap-binding protein subunit 2-like', 'A6PVI3')],
#              'F:cyclosporin A binding': [('Peptidyl-prolyl cis-trans isomerase H',
#                'O43447'),
#               ('Peptidyl-prolyl cis-trans isomerase B', 'P23284'),
#               ('P30405',
#                'Peptidyl-prolyl cis-trans isomerase F, mitochondrial'),
#               ('P30414', 'NK-tumor recognition protein'),
#               ('P45877', 'Peptidyl-prolyl cis-trans isomerase C'),
#               ('Peptidyl-prolyl cis-trans isomerase A', 'P62937'),
#               ('Q08752', 'Peptidyl-prolyl cis-trans isomerase D'),
#               ('Q13427', 'Peptidyl-prolyl cis-trans isomerase G'),
#               ('Peptidyl-prolyl cis-trans isomerase E', 'Q9UNP9'),
#               ('Q8IXY8',
#                'Probable inactive peptidyl-prolyl cis-trans isomerase-like 6'),
#               ('A0A075B759', 'Peptidyl-prolyl cis-trans isomerase A-like 4E'),
#               ('Peptidyl-prolyl cis-trans isomerase A-like 4H', 'A0A075B767'),
#               ('A0A0B4J2A2', 'Peptidyl-prolyl cis-trans isomerase A-like 4C'),
#               ('F5H284', 'Peptidyl-prolyl cis-trans isomerase A-like 4D'),
#               ('Peptidyl-prolyl cis-trans isomerase A-like 4F', 'P0DN26'),
#               ('Peptidyl-prolyl cis-trans isomerase A-like 4G', 'P0DN37'),
#               ('Peptidyl-prolyl cis-trans isomerase A-like 4A', 'Q9Y536')],
#              'F:aldo-keto reductase (NADPH) activity': [('Voltage-gated potassium channel subunit beta-3',
#                'O43448'),
#               ('Aflatoxin B1 aldehyde reductase member 2', 'O43488'),
#               ('O60218', 'Aldo-keto reductase family 1 member B10'),
#               ('Aflatoxin B1 aldehyde reductase member 3', 'O95154'),
#               ('P14550', 'Aldo-keto reductase family 1 member A1'),
#               ('Aldo-keto reductase family 1 member C4', 'P17516'),
#               ('Sepiapterin reductase', 'P35270'),
#               ('P42330', 'Aldo-keto reductase family 1 member C3'),
#               ('Aldo-keto reductase family 1 member D1', 'P51857'),
#               ('Aldo-keto reductase family 1 member C1', 'Q04828'),
#               ('Voltage-gated potassium channel subunit beta-2', 'Q13303'),
#               ('Q14722', 'Voltage-gated potassium channel subunit beta-1'),
#               ('Q8NHP1', 'Aflatoxin B1 aldehyde reductase member 4'),
#               ('Q9UGB7', 'Inositol oxygenase')],
#              'F:voltage-gated potassium channel activity': [('Voltage-gated potassium channel subunit beta-3',
#                'O43448'),
#               ('O43525',
#                'Potassium voltage-gated channel subfamily KQT member 3'),
#               ('O43526',
#                'Potassium voltage-gated channel subfamily KQT member 2'),
#               ('O60741',
#                'Potassium/sodium hyperpolarization-activated cyclic nucleotide-gated channel 1'),
#               ('P16389',
#                'Potassium voltage-gated channel subfamily A member 2'),
#               ('P17658',
#                'Potassium voltage-gated channel subfamily A member 6'),
#               ('P22001',
#                'Potassium voltage-gated channel subfamily A member 3'),
#               ('P22459',
#                'Potassium voltage-gated channel subfamily A member 4'),
#               ('Potassium voltage-gated channel subfamily A member 5',
#                'P22460'),
#               ('P48547', 'Voltage-gated potassium channel KCNC1'),
#               ('Potassium voltage-gated channel subfamily KQT member 1',
#                'P51787'),
#               ('P56696',
#                'Potassium voltage-gated channel subfamily KQT member 4'),
#               ('Synaptosomal-associated protein 25', 'P60880'),
#               ('Q03721', 'Voltage-gated potassium channel KCNC4'),
#               ('Q09470',
#                'Potassium voltage-gated channel subfamily A member 1'),
#               ('Q12791',
#                'Calcium-activated potassium channel subunit alpha-1'),
#               ('Q12809',
#                'Voltage-gated inwardly rectifying potassium channel KCNH2'),
#               ('Voltage-gated potassium channel subunit beta-2', 'Q13303'),
#               ('Polycystin-2', 'Q13563'),
#               ('Voltage-gated potassium channel KCNC3', 'Q14003'),
#               ('ATP-sensitive inward rectifier potassium channel 11',
#                'Q14654'),
#               ('Q14722', 'Voltage-gated potassium channel subunit beta-1'),
#               ('Q16322',
#                'Potassium voltage-gated channel subfamily A member 10'),
#               ('Leucine-rich repeat-containing protein 26', 'Q2I0M4'),
#               ('Q5VT99', 'Leucine-rich repeat-containing protein 38'),
#               ('Q6PIU1',
#                'Potassium voltage-gated channel subfamily V member 1'),
#               ('Q6ZSA7', 'Leucine-rich repeat-containing protein 55'),
#               ('Leucine-rich repeat-containing protein 52', 'Q8N7C0'),
#               ('Q8NCM2',
#                'Voltage-gated delayed rectifier potassium channel KCNH5'),
#               ('Potassium voltage-gated channel subfamily V member 2',
#                'Q8TDN2'),
#               ('Potassium voltage-gated channel subfamily E member 4',
#                'Q8WWG9'),
#               ('Voltage-gated delayed rectifier potassium channel KCNH8',
#                'Q96L42'),
#               ('Voltage-gated potassium channel KCNC2', 'Q96PR1'),
#               ('Q9BQ31',
#                'Delayed-rectifier potassium channel regulatory subunit KCNS3'),
#               ('Q9H3M0',
#                'Voltage-gated potassium channel regulatory subunit KCNF1'),
#               ('Q9NR82',
#                'Potassium voltage-gated channel subfamily KQT member 5'),
#               ('A-type voltage-gated potassium channel KCND2', 'Q9NZV8'),
#               ('Q9P1Z3',
#                'Potassium/sodium hyperpolarization-activated cyclic nucleotide-gated channel 3'),
#               ('Q9UJ90',
#                'Potassium voltage-gated channel subfamily E regulatory beta subunit 5'),
#               ('Q9UJ96',
#                'Voltage-gated potassium channel regulatory subunit KCNG2'),
#               ('Q9UK17', 'A-type voltage-gated potassium channel KCND3'),
#               ('Q9UL51',
#                'Potassium/sodium hyperpolarization-activated cyclic nucleotide-gated channel 2'),
#               ('Q9ULD8',
#                'Voltage-gated inwardly rectifying potassium channel KCNH3'),
#               ('Voltage-gated delayed rectifier potassium channel KCNH4',
#                'Q9UQ05'),
#               ('Q9Y3Q4',
#                'Potassium/sodium hyperpolarization-activated cyclic nucleotide-gated channel 4'),
#               ('Q9Y6H6',
#                'Potassium voltage-gated channel subfamily E member 3'),
#               ('Delayed-rectifier potassium channel regulatory subunit KCNS2',
#                'Q9ULS6')],
#              'F:alpha-1,4-glucosidase activity': [('O43451',
#                'Maltase-glucoamylase'),
#               ('P10253', 'Lysosomal alpha-glucosidase'),
#               ('Sucrase-isomaltase, intestinal', 'P14410'),
#               ('Probable maltase-glucoamylase 2', 'Q2M2H8'),
#               ('Neutral alpha-glucosidase C', 'Q8TET4')],
#              'F:amylase activity': [('O43451', 'Maltase-glucoamylase')],
#              'F:glucan 1,4-alpha-glucosidase activity': [('O43451',
#                'Maltase-glucoamylase'),
#               ('Probable maltase-glucoamylase 2', 'Q2M2H8')],
#              'F:transcription regulator activator activity': [('Membrane-bound transcription factor site-2 protease',
#                'O43462'),
#               ('Myc proto-oncogene protein', 'P01106'),
#               ('P09874', 'Poly [ADP-ribose] polymerase 1'),
#               ('P19419', 'ETS domain-containing protein Elk-1'),
#               ('DNA damage-inducible transcript 3 protein', 'P35638'),
#               ('P46531', 'Neurogenic locus notch homolog protein 1'),
#               ('Serine/threonine-protein kinase 3', 'Q13188'),
#               ('Q16665', 'Hypoxia-inducible factor 1-alpha'),
#               ('Bifunctional arginine demethylase and lysyl-hydroxylase JMJD6',
#                'Q6NYC1'),
#               ('Histone-lysine N-methyltransferase NSD3', 'Q9BZ95'),
#               ('Q9H4B6', 'Protein salvador homolog 1'),
#               ('Q9NZM4',
#                'BRD4-interacting chromatin-remodeling complex-associated protein')],
#              'F:histone H3K9 methyltransferase activity': [('O43463',
#                'Histone-lysine N-methyltransferase SUV39H1'),
#               ('Histone-lysine N-methyltransferase MECOM', 'Q03112'),
#               ('Histone-lysine N-methyltransferase SETDB1', 'Q15047'),
#               ('Q96KQ7', 'Histone-lysine N-methyltransferase EHMT2'),
#               ('Histone-lysine N-methyltransferase SETDB2', 'Q96T68'),
#               ('Histone-lysine N-methyltransferase SETD5', 'Q9C0A6'),
#               ('Histone-lysine N-methyltransferase SUV39H2', 'Q9H5I1'),
#               ('Histone-lysine N-methyltransferase EHMT1', 'Q9H9B1'),
#               ('Histone-lysine N-methyltransferase PRDM16', 'Q9HAZ2'),
#               ('PR domain zinc finger protein 8', 'Q9NQV8'),
#               ('Q9NR48', 'Histone-lysine N-methyltransferase ASH1L')],
#              'F:histone H3K9 trimethyltransferase activity': [('O43463',
#                'Histone-lysine N-methyltransferase SUV39H1'),
#               ('PR domain zinc finger protein 2', 'Q13029'),
#               ('Histone-lysine N-methyltransferase SETDB1', 'Q15047'),
#               ('Histone-lysine N-methyltransferase SUV39H2', 'Q9H5I1'),
#               ('Histone-lysine N-methyltransferase PRDM9', 'Q9NQV7')],
#              'F:ubiquitin ligase inhibitor activity': [('Serine protease HTRA2, mitochondrial',
#                'O43464'),
#               ('Large ribosomal subunit protein uL18', 'P46777'),
#               ('P60866', 'Small ribosomal subunit protein uS10'),
#               ('Large ribosomal subunit protein eL37', 'P61927'),
#               ('P62081', 'Small ribosomal subunit protein eS7'),
#               ('P62829', 'Large ribosomal subunit protein uL14'),
#               ('Small ribosomal subunit protein uS19', 'P62841'),
#               ('P62913', 'Large ribosomal subunit protein uL5'),
#               ('Tumor suppressor ARF', 'Q8N726'),
#               ('Q9UKT4', 'F-box only protein 5')],
#              'F:RNA polymerase II sequence-specific DNA-binding transcription factor recruiting activity': [('O43474',
#                'Krueppel-like factor 4')],
#              'F:phenanthrene-9,10-epoxide hydrolase activity': [('Aflatoxin B1 aldehyde reductase member 2',
#                'O43488')],
#              'F:actinin binding': [('Prominin-1', 'O43490'),
#               ('P19838', 'Nuclear factor NF-kappa-B p105 subunit'),
#               ('P21291', 'Cysteine and glycine-rich protein 1'),
#               ('Cysteine and glycine-rich protein 3', 'P50461'),
#               ('Transcription factor p65', 'Q04206'),
#               ('Polycystin-2', 'Q13563'),
#               ('Q16527', 'Cysteine and glycine-rich protein 2'),
#               ('Q8IY33', 'MICAL-like protein 2'),
#               ('Q8WZ42', 'Titin'),
#               ('PDZ and LIM domain protein 5', 'Q96HC4'),
#               ('Myozenin-1', 'Q9NP98'),
#               ('Q9UL62', 'Short transient receptor potential channel 5')],
#              'F:PH domain binding': [('O43491', 'Band 4.1-like protein 2'),
#               ('Nucleolin', 'P19338'),
#               ('P36776', 'Lon protease homolog, mitochondrial'),
#               ('Ephrin type-A receptor 4', 'P54764'),
#               ('P58004', 'Sestrin-2'),
#               ('Q14642', 'Inositol polyphosphate-5-phosphatase A'),
#               ('Q9Y4Z0', 'U6 snRNA-associated Sm-like protein LSm4'),
#               ('Q92610', 'Zinc finger protein 592')],
#              'F:low voltage-gated calcium channel activity': [('O43497',
#                'Voltage-dependent T-type calcium channel subunit alpha-1G'),
#               ('O95180',
#                'Voltage-dependent T-type calcium channel subunit alpha-1H')],
#              'F:voltage-gated calcium channel activity involved in AV node cell action potential': [('O43497',
#                'Voltage-dependent T-type calcium channel subunit alpha-1G'),
#               ('Q13936',
#                'Voltage-dependent L-type calcium channel subunit alpha-1C')],
#              'F:voltage-gated calcium channel activity involved SA node cell action potential': [('O43497',
#                'Voltage-dependent T-type calcium channel subunit alpha-1G'),
#               ('Q01668',
#                'Voltage-dependent L-type calcium channel subunit alpha-1D')],
#              'F:crossover junction DNA endonuclease activity': [('DNA repair protein RAD51 homolog 3',
#                'O43502'),
#               ('Flap endonuclease GEN homolog 1', 'Q17RS7'),
#               ('Crossover junction endonuclease MUS81', 'Q96NY9'),
#               ('Q9BQ83', 'Structure-specific endonuclease subunit SLX1')],
#              'F:glucuronosyltransferase activity': [('O43505',
#                'Beta-1,4-glucuronyltransferase 1'),
#               ('O60656', 'UDP-glucuronosyltransferase 1A9'),
#               ('O75795', 'UDP-glucuronosyltransferase 2B17'),
#               ('O94766',
#                'Galactosylgalactosylxylosylprotein 3-beta-glucuronosyltransferase 3'),
#               ('O95461', 'Xylosyl- and glucuronyltransferase LARGE1'),
#               ('P06133', 'UDP-glucuronosyltransferase 2B4'),
#               ('P0DTE4', 'UDP-glucuronosyltransferase 2A1'),
#               ('P0DTE5', 'UDP-glucuronosyltransferase 2A2'),
#               ('P16662', 'UDP-glucuronosyltransferase 2B7'),
#               ('P19224', 'UDP-glucuronosyltransferase 1-6'),
#               ('P22309', 'UDP-glucuronosyltransferase 1A1'),
#               ('P22310', 'UDP-glucuronosyltransferase 1A4'),
#               ('UDP-glucuronosyltransferase 1A3', 'P35503'),
#               ('P35504', 'UDP-glucuronosyltransferase 1A5'),
#               ('UDP-glucuronosyltransferase 2B15', 'P54855'),
#               ('Exostosin-1', 'Q16394'),
#               ('Q8N3Y3', 'Xylosyl- and glucuronyltransferase LARGE2'),
#               ('Chondroitin sulfate N-acetylgalactosaminyltransferase 1',
#                'Q8TDX6'),
#               ('Q92935', 'Exostosin-like 1'),
#               ('Exostosin-2', 'Q93063'),
#               ('UDP-glucuronosyltransferase 2B28', 'Q9BY64'),
#               ('UDP-glucuronosyltransferase 1A7', 'Q9HAW7'),
#               ('UDP-glucuronosyltransferase 1A10', 'Q9HAW8'),
#               ('Q9HAW9', 'UDP-glucuronosyltransferase 1A8'),
#               ('UDP-glucuronosyltransferase 2B11', 'O75310'),
#               ('UDP-glucuronosyltransferase 3A2', 'Q3SY77'),
#               ('UDP-glucuronosyltransferase 3A1', 'Q6NUS8'),
#               ('UDP-glucuronosyltransferase 2A3', 'Q6UWM9')],
#              'F:N-acetyllactosaminide beta-1,3-N-acetylglucosaminyltransferase activity': [('O43505',
#                'Beta-1,4-glucuronyltransferase 1'),
#               ('UDP-GlcNAc:betaGal beta-1,3-N-acetylglucosaminyltransferase 7',
#                'Q8NFL0'),
#               ('Q9BYG0',
#                'Lactosylceramide 1,3-N-acetyl-beta-D-glucosaminyltransferase'),
#               ('Q9C0J1',
#                'N-acetyllactosaminide beta-1,3-N-acetylglucosaminyltransferase 4'),
#               ('N-acetyllactosaminide beta-1,3-N-acetylglucosaminyltransferase 2',
#                'Q9NY97'),
#               ('N-acetyllactosaminide beta-1,3-N-acetylglucosaminyltransferase 3',
#                'Q9Y2A9')],
#              ...})

# %%
import matplotlib as plt

    
import matplotlib.pyplot as plt
from collections import Counter

def analyze_go_distribution_large(go_to_proteins, top_n=100):
    """
    Analyzes and visualizes the distribution of GO terms.

    Parameters:
        go_to_proteins (dict): A dictionary mapping GO terms to protein IDs.
        top_n (int): Number of top GO terms to display in the plot. Default is 20.
    """
    # Count the occurrences of each GO term
    go_counts = {go: len(proteins) for go, proteins in go_to_proteins.items()}

    # Sort and select the top N GO terms
    top_go_counts = dict(Counter(go_counts).most_common(top_n))

    # Dynamically adjust figure size based on the number of terms
    height_per_bar = 0.5
    total_height = height_per_bar * len(top_go_counts)
    plt.figure(figsize=(12, max(8, total_height)))

    # Plot the distribution
    plt.barh(list(top_go_counts.keys()), list(top_go_counts.values()), color='skyblue')
    plt.xlabel('Frequency (Number of Proteins)')
    plt.ylabel('GO Terms')
    plt.title(f'Top {top_n} GO Terms Distribution')
    plt.gca().invert_yaxis()  # Invert y-axis to show the most frequent GO term at the top
    plt.tight_layout()
    plt.show()

# %%
analyze_go_distribution_large(go_to_proteins, top_n=30)

# %%
def get_protein_names(go_to_proteins, go_term):
    return go_to_proteins[go_term]

# %%
proteins_for_metal_ion = get_protein_names(go_to_proteins, "F:metal ion binding")
proteins_for_metal_ion
# Out:
# [('Ciliated left-right organizer metallopeptidase', 'A0A1B0GTW7'),
#  ('A0AVI4', 'E3 ubiquitin-protein ligase TM129'),
#  ('Fez family zinc finger protein 1', 'A0PJY2'),
#  ('Protein FAM170A', 'A1A519'),
#  ('A1KZ92', 'Probable oxidoreductase PXDNL'),
#  ('A2A288', 'Probable ribonuclease ZC3H12D'),
#  ('Metallo-beta-lactamase domain-containing protein 1', 'A4D2B0'),
#  ('A5YM72', 'Carnosine synthase 1'),
#  ('A6NFA1', 'Metalloprotease TIKI2'),
#  ('Tubulin alpha chain-like 3', 'A6NHL2'),
#  ('Wilms tumor protein 1-interacting protein', 'A6NIX2'),
#  ('Tubulin polyglutamylase TTLL13', 'A6NNM8'),
#  ('Tubulin beta 8B', 'A6NNZ2'),
#  ('A6PVC2', 'Protein monoglycylase TTLL8'),
#  ('A7MCY6', 'TANK-binding kinase 1-binding protein 1'),
#  ('Sine oculis-binding protein homolog', 'A7XYQ1'),
#  ('Calcium-activated chloride channel regulator 1', 'A8K7I4'),
#  ('A8K8V0', 'Zinc finger protein 785'),
#  ('A8MQ27', 'E3 ubiquitin-protein ligase NEURL1B'),
#  ('A8MTJ3', 'Guanine nucleotide-binding protein G(t) subunit alpha-3'),
#  ('PHD finger protein 20-like protein 1', 'A8MW92'),
#  ('Unconventional myosin-IXa', 'B2RTY4'),
#  ('B2RXF5', 'Zinc finger and BTB domain-containing protein 42'),
#  ('B2RXH2', 'Lysine-specific demethylase 4E'),
#  ('O00151', 'PDZ and LIM domain protein 1'),
#  ('O00217',
#   'NADH dehydrogenase [ubiquinone] iron-sulfur protein 8, mitochondrial'),
#  ('E3 ubiquitin-protein ligase RNF103', 'O00237'),
#  ('Bone morphogenetic protein receptor type-1B', 'O00238'),
#  ('O00264', 'Membrane-associated progesterone receptor component 1'),
#  ('Cell division cycle 7-related protein kinase', 'O00311'),
#  ('LINE-1 retrotransposable element ORF2 protein', 'O00370'),
#  ('O00487', '26S proteasome non-ATPase regulatory subunit 14'),
#  ('O00506', 'Serine/threonine-protein kinase 25'),
#  ('Ubiquitin carboxyl-terminal hydrolase 9Y', 'O00507'),
#  ('O00555', 'Voltage-dependent P/Q-type calcium channel subunit alpha-1A'),
#  ('Beta-1,3-N-acetylglucosaminyltransferase manic fringe', 'O00587'),
#  ('O00602', 'Ficolin-1'),
#  ('O00625', 'Pirin'),
#  ('O00743', 'Serine/threonine-protein phosphatase 6 catalytic subunit'),
#  ('O00746', 'Nucleoside diphosphate kinase, mitochondrial'),
#  ('O00754', 'Lysosomal alpha-mannosidase'),
#  ('Fructose-1,6-bisphosphatase isozyme 2', 'O00757'),
#  ('Acetyl-CoA carboxylase 2', 'O00763'),
#  ('O14521',
#   'Succinate dehydrogenase [ubiquinone] cytochrome b small subunit, mitochondrial'),
#  ('O14569', 'Transmembrane reductase CYB561D2'),
#  ('O14578', 'Citron Rho-interacting kinase'),
#  ('Carboxy-terminal domain RNA polymerase II polypeptide A small phosphatase 2',
#   'O14595'),
#  ('Histone demethylase UTY', 'O14607'),
#  ('Actin-binding LIM protein 1', 'O14639'),
#  ('Disintegrin and metalloproteinase domain-containing protein 10', 'O14672'),
#  ('O14686', 'Histone-lysine N-methyltransferase 2D'),
#  ('O14730', 'Serine/threonine-protein kinase RIO3'),
#  ('O14732', 'Inositol monophosphatase 2'),
#  ('CDP-diacylglycerol--inositol 3-phosphatidyltransferase', 'O14735'),
#  ('O14746', 'Telomerase reverse transcriptase'),
#  ('Zinc finger protein 213', 'O14771'),
#  ('Tripeptidyl-peptidase 1', 'O14773'),
#  ('Neuropilin-1', 'O14786'),
#  ('O14863', 'Probable proton-coupled zinc antiporter SLC30A4'),
#  ('Krueppel-like factor 11', 'O14901'),
#  ('O14960', 'Leukocyte cell-derived chemotaxin-2'),
#  ('Hepatocyte growth factor-regulated tyrosine kinase substrate', 'O14964'),
#  ('O14978', 'Zinc finger protein 263'),
#  ('O15014', 'Zinc finger protein 609'),
#  ('Zinc finger protein 646', 'O15015'),
#  ('Lysine-specific demethylase 6B', 'O15054'),
#  ('O15060', 'Zinc finger and BTB domain-containing protein 39'),
#  ('Zinc finger and BTB domain-containing protein 5', 'O15062'),
#  ('O15067', 'Phosphoribosylformylglycinamidine synthase'),
#  ('Mitochondrial ribonuclease P catalytic subunit', 'O15091'),
#  ('O15105', 'Mothers against decapentaplegic homolog 7'),
#  ('O15123', 'Angiopoietin-2'),
#  ('Muscle, skeletal receptor tyrosine-protein kinase', 'O15146'),
#  ('Zinc finger and BTB domain-containing protein 7B', 'O15156'),
#  ('O15194', 'CTD small phosphatase-like protein'),
#  ('Mothers against decapentaplegic homolog 9', 'O15198'),
#  ('O15209', 'Zinc finger and BTB domain-containing protein 22'),
#  ('Protein phosphatase 1D', 'O15297'),
#  ('Apoptosis regulatory protein Siva', 'O15304'),
#  ('O15305', 'Phosphomannomutase 2'),
#  ('O15350', 'Tumor protein p73'),
#  ('Protein phosphatase 1G', 'O15355'),
#  ('O15391', 'Transcription factor YY2'),
#  ('Baculoviral IAP repeat-containing protein 5', 'O15392'),
#  ('O15409', 'Forkhead box protein P2'),
#  ('O15488', 'Glycogenin-2'),
#  ('O15504', 'Nucleoporin NUP42'),
#  ('Zinc finger and SCAN domain-containing protein 9', 'O15535'),
#  ('E3 ubiquitin-protein ligase RNF113A', 'O15541'),
#  ('Lysine-specific demethylase 6A', 'O15550'),
#  ('O43150',
#   'Arf-GAP with SH3 domain, ANK repeat and PH domain-containing protein 2'),
#  ('E3 ubiquitin-protein ligase Praja-2', 'O43164'),
#  ('Zinc finger and BTB domain-containing protein 24', 'O43167'),
#  ('Cytochrome b5 type B', 'O43169'),
#  ('O43184', 'Disintegrin and metalloproteinase domain-containing protein 12'),
#  ('PHD finger protein 1', 'O43189'),
#  ('O43194', 'G-protein coupled receptor 39'),
#  ('O43257', 'Zinc finger HIT domain-containing protein 1'),
#  ('Mitogen-activated protein kinase kinase kinase 13', 'O43283'),
#  ('Beta-1,4-galactosyltransferase 5', 'O43286'),
#  ('Transforming growth factor beta-1-induced transcript 1 protein', 'O43294'),
#  ('Zinc finger protein 264', 'O43296'),
#  ('Zinc finger and BTB domain-containing protein 43', 'O43298'),
#  ('O43306', 'Adenylate cyclase type 6'),
#  ('Zinc finger and SCAN domain-containing protein 12', 'O43309'),
#  ('O43313', 'ATM interactor'),
#  ('Ras GTPase-activating protein 4', 'O43374'),
#  ('52 kDa repressor of the inhibitor of the protein kinase', 'O43422'),
#  ('O43439', 'Protein CBFA2T2'),
#  ('Membrane-bound transcription factor site-2 protease', 'O43462'),
#  ('O43482', 'Protein Mis18-beta'),
#  ('O43505', 'Beta-1,4-glucuronyltransferase 1'),
#  ('O43506', 'Disintegrin and metalloproteinase domain-containing protein 20'),
#  ('Mothers against decapentaplegic homolog 6', 'O43541'),
#  ('Protein-glutamine gamma-glutamyltransferase 5', 'O43548'),
#  ('E3 ubiquitin-protein ligase RNF13', 'O43567'),
#  ('O43593', 'Lysine-specific demethylase hairless'),
#  ('O43623', 'Zinc finger protein SNAI2'),
#  ('O43670', 'BUB3-interacting and GLEBS motif-containing protein ZNF207'),
#  ('O43681', 'ATPase GET3'),
#  ('Lipoyl synthase, mitochondrial', 'O43766'),
#  ('O43829', 'Zinc finger and BTB domain-containing protein 14'),
#  ('O43847', 'Nardilysin'),
#  ('O43895', 'Xaa-Pro aminopeptidase 2'),
#  ('TYRO protein tyrosine kinase-binding protein', 'O43914'),
#  ('O60229', 'Kalirin'),
#  ('O60266', 'Adenylate cyclase type 3'),
#  ('Zinc finger protein 292', 'O60281'),
#  ('O60285', 'NUAK family SNF1-like kinase 1'),
#  ('O60291', 'E3 ubiquitin-protein ligase MGRN1'),
#  ('O60293', 'Zinc finger C3H1 domain-containing protein'),
#  ('O60304', 'Zinc finger protein 500'),
#  ('O60315', 'Zinc finger E-box-binding homeobox 2'),
#  ('PH domain leucine-rich repeat-containing protein phosphatase 1', 'O60346'),
#  ('Neuropilin-2', 'O60462'),
#  ('O60481', 'Zinc finger protein ZIC 3'),
#  ('Adenylate cyclase type 9', 'O60503'),
#  ('Beta-1,4-galactosyltransferase 3', 'O60512'),
#  ('Beta-1,4-galactosyltransferase 4', 'O60513'),
#  ('Multifunctional procollagen lysine hydroxylase and glycosyltransferase LH3',
#   'O60568'),
#  ("High affinity cAMP-specific and IBMX-insensitive 3',5'-cyclic phosphodiesterase 8A",
#   'O60658'),
#  ('LIM homeobox transcription factor 1-beta', 'O60663'),
#  ('O60673', 'DNA polymerase zeta catalytic subunit'),
#  ('O60674', 'Tyrosine-protein kinase JAK2'),
#  ('O60678', 'Protein arginine N-methyltransferase 3'),
#  ('Leupaxin', 'O60711'),
#  ('Dolichol-phosphate mannosyltransferase subunit 1', 'O60762'),
#  ('O60840', 'Voltage-dependent L-type calcium channel subunit alpha-1F'),
#  ('Eukaryotic translation initiation factor 5B', 'O60841'),
#  ('O60870', 'DNA/RNA-binding protein KIN17'),
#  ('O60884', 'DnaJ homolog subfamily A member 2'),
#  ('O60906', 'Sphingomyelin phosphodiesterase 2'),
#  ('O60909', 'Beta-1,4-galactosyltransferase 2'),
#  ('Glycosaminoglycan xylosylkinase', 'O75063'),
#  ('O75081', 'Protein CBFA2T3'),
#  ('LIM domain-binding protein 3', 'O75112'),
#  ('Rho-associated protein kinase 2', 'O75116'),
#  ('Copine-3', 'O75131'),
#  ('O75132', 'Zinc finger BED domain-containing protein 4'),
#  ('O75150', 'E3 ubiquitin-protein ligase BRE1B'),
#  ('O75152', 'Zinc finger CCCH domain-containing protein 11A'),
#  ('O75185', 'Calcium-transporting ATPase type 2C member 2'),
#  ('NADH dehydrogenase [ubiquinone] iron-sulfur protein 7, mitochondrial',
#   'O75251'),
#  ('O75306',
#   'NADH dehydrogenase [ubiquinone] iron-sulfur protein 2, mitochondrial'),
#  ('O75311', 'Glycine receptor subunit alpha-3'),
#  ('Ubiquitin carboxyl-terminal hydrolase 12', 'O75317'),
#  ('Stannin', 'O75324'),
#  ('O75343', 'Guanylate cyclase soluble subunit beta-2'),
#  ('Zinc finger protein 217', 'O75362'),
#  ('O75398', 'Deformed epidermal autoregulatory factor 1 homolog'),
#  ('O75414', 'Nucleoside diphosphate kinase 6'),
#  ('O75439', 'Mitochondrial-processing peptidase subunit beta'),
#  ('O75446', 'Histone deacetylase complex subunit SAP30'),
#  ('O75578', 'Integrin alpha-10'),
#  ('O75603', 'Chorion-specific transcription factor GCMb'),
#  ('O75604', 'Ubiquitin carboxyl-terminal hydrolase 2'),
#  ('O75626', 'PR domain zinc finger protein 1'),
#  ('Ficolin-3', 'O75636'),
#  ('Ret finger protein-like 1', 'O75677'),
#  ('Ret finger protein-like 2', 'O75678'),
#  ('Ret finger protein-like 3', 'O75679'),
#  ('Arf-GAP with dual PH domain-containing protein 1', 'O75689'),
#  ('Ribonuclease H2 subunit A', 'O75792'),
#  ('Zinc finger MYND domain-containing protein 10', 'O75800'),
#  ('Calpain-15', 'O75808'),
#  ('O75844', 'CAAX prenyl protease 1 homolog'),
#  ('O75912', 'Diacylglycerol kinase iota'),
#  ('Serine/threonine-protein kinase PAK 3', 'O75914'),
#  ('O76003', 'Glutaredoxin-3'),
#  ('O76050', 'E3 ubiquitin-protein ligase NEURL1'),
#  ("cGMP-specific 3',5'-cyclic phosphodiesterase", 'O76074'),
#  ("High affinity cGMP-specific 3',5'-cyclic phosphodiesterase 9A", 'O76083'),
#  ('N(G),N(G)-dimethylarginine dimethylaminohydrolase 1', 'O94760'),
#  ('O94761', 'ATP-dependent DNA helicase Q4'),
#  ('ATP-dependent DNA helicase Q5', 'O94762'),
#  ('O94766',
#   'Galactosylgalactosylxylosylprotein 3-beta-glucuronosyltransferase 3'),
#  ('O94776', 'Metastasis-associated protein MTA2'),
#  ('O94806', 'Serine/threonine-protein kinase D3'),
#  ('O94830', 'Triacylglycerol hydrolase DDHD2'),
#  ('[F-actin]-monooxygenase MICAL2', 'O94851'),
#  ('Zinc finger protein 432', 'O94892'),
#  ('O94919', 'Endonuclease domain-containing 1 protein'),
#  ('Actin-binding LIM protein 3', 'O94929'),
#  ('O94941', 'RING finger protein 37'),
#  ('Lysine-specific demethylase 4B', 'O94953'),
#  ('Ubiquitin carboxyl-terminal hydrolase 19', 'O94966'),
#  ('O95069', 'Potassium channel subfamily K member 2'),
#  ('Zinc finger protein 202', 'O95125'),
#  ('O95171', 'Sciellin'),
#  ('O95180', 'Voltage-dependent T-type calcium channel subunit alpha-1H'),
#  ('Zinc finger Ran-binding domain-containing protein 2', 'O95218'),
#  ('O95239', 'Chromosome-associated kinesin KIF4A'),
#  ("High affinity cAMP-specific and IBMX-insensitive 3',5'-cyclic phosphodiesterase 8B",
#   'O95263'),
#  ('O95294', 'RasGAP-activating-like protein 1'),
#  ('O95365', 'Zinc finger and BTB domain-containing protein 7A'),
#  ('O95396', 'Adenylyltransferase and sulfurtransferase MOCS3'),
#  ('Zinc finger FYVE domain-containing protein 9', 'O95405'),
#  ('O95409', 'Zinc finger protein ZIC 2'),
#  ('O95453', 'Poly(A)-specific ribonuclease PARN'),
#  ('NAD kinase', 'O95544'),
#  ('O95600', 'Krueppel-like factor 8'),
#  ('Adenylate cyclase type 5', 'O95622'),
#  ('O95628', 'CCR4-NOT transcription complex subunit 4'),
#  ('O95630', 'STAM-binding protein'),
#  ('O95672', 'Endothelin-converting enzyme-like 1'),
#  ('Eyes absent homolog 4', 'O95677'),
#  ('Bromodomain-containing protein 1', 'O95696'),
#  ('O95749', 'Geranylgeranyl pyrophosphate synthase'),
#  ('O95785', 'Protein Wiz'),
#  ('Guanine nucleotide-binding protein subunit alpha-14', 'O95837'),
#  ('Uridine diphosphate glucose pyrophosphatase NUDT14', 'O95848'),
#  ('O95861', "3'(2'),5'-bisphosphate nucleotidase 1"),
#  ('Zinc finger protein SNAI1', 'O95863'),
#  ('Polyglutamylase complex subunit TTLL1', 'O95922'),
#  ('Protein-glutamine gamma-glutamyltransferase 6', 'O95932'),
#  ('E3 SUMO-protein ligase ZBED1', 'O96006'),
#  ('Serine/threonine-protein kinase Chk2', 'O96017'),
#  ('O96028', 'Histone-lysine N-methyltransferase NSD2'),
#  ('Cytochrome b', 'P00156'),
#  ('P00167', 'Cytochrome b5'),
#  ('P00395', 'Cytochrome c oxidase subunit 1'),
#  ('P00488', 'Coagulation factor XIII A chain'),
#  ('Coagulation factor IX', 'P00740'),
#  ('P00973', "2'-5'-oligoadenylate synthase 1"),
#  ('Somatotropin', 'P01241'),
#  ('Hemoglobin subunit delta', 'P02042'),
#  ('P02100', 'Hemoglobin subunit epsilon'),
#  ('P02144', 'Myoglobin'),
#  ('P02452', 'Collagen alpha-1(I) chain'),
#  ('P02458', 'Collagen alpha-1(II) chain'),
#  ('P02461', 'Collagen alpha-1(III) chain'),
#  ('Alpha-crystallin A chain', 'P02489'),
#  ('P02511', 'Alpha-crystallin B chain'),
#  ('P02671', 'Fibrinogen alpha chain'),
#  ('P02679', 'Fibrinogen gamma chain'),
#  ('P02771', 'Alpha-fetoprotein'),
#  ('Hemopexin', 'P02790'),
#  ('P02795', 'Metallothionein-2'),
#  ('P04040', 'Catalase'),
#  ('P04049', 'RAF proto-oncogene serine/threonine-protein kinase'),
#  ('DNA nucleotidylexotransferase', 'P04053'),
#  ('Histidine-rich glycoprotein', 'P04196'),
#  ('Metallothionein-1A', 'P04731'),
#  ('Metallothionein-1E', 'P04732'),
#  ('P04733', 'Metallothionein-1F'),
#  ('P04839', 'Cytochrome b-245 heavy chain'),
#  ('P04899', 'Guanine nucleotide-binding protein G(i) subunit alpha-2'),
#  ('P05106', 'Integrin beta-3'),
#  ('Integrin beta-2', 'P05107'),
#  ('Complement factor I', 'P05156'),
#  ('P05164', 'Myeloperoxidase'),
#  ('Propionyl-CoA carboxylase alpha chain, mitochondrial', 'P05165'),
#  ('P05997', 'Collagen alpha-2(V) chain'),
#  ('Tyrosine-protein kinase Fyn', 'P06241'),
#  ('Complement C2', 'P06681'),
#  ('Low affinity immunoglobulin epsilon Fc receptor', 'P06734'),
#  ('P06746', 'DNA polymerase beta'),
#  ('P06756', 'Integrin alpha-V'),
#  ('Asialoglycoprotein receptor 1', 'P07306'),
#  ('P07437', 'Tubulin beta chain'),
#  ('Metallothionein-1B', 'P07438'),
#  ('Serine protease 1', 'P07477'),
#  ('Transcription factor Sp1', 'P08047'),
#  ('Zinc finger Y-chromosomal protein', 'P08048'),
#  ('P08100', 'Rhodopsin'),
#  ('P08123', 'Collagen alpha-2(I) chain'),
#  ('Zinc finger protein GLI1', 'P08151'),
#  ('ATP-dependent 6-phosphofructokinase, muscle type', 'P08237'),
#  ('Integrin alpha-IIb', 'P08514'),
#  ('P08559',
#   'Pyruvate dehydrogenase E1 component subunit alpha, somatic form, mitochondrial'),
#  ('P08574', 'Cytochrome c1, heme protein, mitochondrial'),
#  ('Guanine nucleotide-binding protein G(i) subunit alpha-3', 'P08754'),
#  ('Steryl-sulfatase', 'P08842'),
#  ('P09467', 'Fructose-1,6-bisphosphatase 1'),
#  ('Guanine nucleotide-binding protein G(o) subunit alpha', 'P09471'),
#  ('P09601', 'Heme oxygenase 1'),
#  ('Furin', 'P09958'),
#  ('P0C7P0', 'CDGSH iron-sulfur domain-containing protein 3, mitochondrial'),
#  ('Zinc finger protein 688', 'P0C7X2'),
#  ('Bifunctional peptidase and (3S)-lysyl hydroxylase JMJD7', 'P0C870'),
#  ('Chorionic somatomammotropin hormone 1', 'P0DML2'),
#  ('P0DML3', 'Chorionic somatomammotropin hormone 2'),
#  ('P0DPD6', 'Endothelin-converting enzyme 2'),
#  ('EEF1AKMT4-ECE2 readthrough transcript protein', 'P0DPD8'),
#  ('Tubulin alpha-3C chain', 'P0DPH7'),
#  ('P0DPH8', 'Tubulin alpha-3D chain'),
#  ('P10071', 'Transcriptional activator GLI3'),
#  ('Zinc finger and SCAN domain-containing protein 22', 'P10073'),
#  ('P10074', 'Telomere zinc finger-associated protein'),
#  ('P10155', 'RNA-binding protein RO60'),
#  ('P10398', 'Serine/threonine-protein kinase A-Raf'),
#  ('P10606', 'Cytochrome c oxidase subunit 5B, mitochondrial'),
#  ('P10696', 'Alkaline phosphatase, germ cell type'),
#  ('Mast/stem cell growth factor receptor Kit', 'P10721'),
#  ('P11161', 'E3 SUMO-protein ligase EGR2'),
#  ('Pyruvate dehydrogenase E1 component subunit beta, mitochondrial', 'P11177'),
#  ('Integrin alpha-M', 'P11215'),
#  ('P11488', 'Guanine nucleotide-binding protein G(t) subunit alpha-1'),
#  ('P11498', 'Pyruvate carboxylase, mitochondrial'),
#  ('P11678', 'Eosinophil peroxidase'),
#  ('Collagen alpha-1(XI) chain', 'P12107'),
#  ("Inosine-5'-monophosphate dehydrogenase 2", 'P12268'),
#  ('2-oxoisovalerate dehydrogenase subunit alpha, mitochondrial', 'P12694'),
#  ('Cytochrome b-245 light chain', 'P13498'),
#  ('P13612', 'Integrin alpha-4'),
#  ('Sodium/potassium-transporting ATPase subunit alpha-3', 'P13637'),
#  ('P13640', 'Metallothionein-1G'),
#  ('Zinc finger protein 35', 'P13682'),
#  ('P13942', 'Collagen alpha-2(XI) chain'),
#  ('Farnesyl pyrophosphate synthase', 'P14324'),
#  ('P14373', 'Zinc finger protein RFP'),
#  ('Indoleamine 2,3-dioxygenase 1', 'P14902'),
#  ('Glutamine synthetase', 'P15104'),
#  ('P15336', 'Cyclic AMP-dependent transcription factor ATF-2'),
#  ('P15498', 'Proto-oncogene vav'),
#  ('Histatin-3', 'P15516'),
#  ('N-acetylglucosamine-6-sulfatase', 'P15586'),
#  ('Zinc finger protein 250', 'P15622'),
#  ('P15822', 'Zinc finger protein 40'),
#  ('P15848', 'Arylsulfatase B'),
#  ('N-chimaerin', 'P15882'),
#  ('V(D)J recombination-activating protein 1', 'P15918'),
#  ('Aggrecan core protein', 'P16112'),
#  ('P16144', 'Integrin beta-4'),
#  ('Pancreatic triacylglycerol lipase', 'P16233'),
#  ('Methylated-DNA--protein-cysteine methyltransferase', 'P16455'),
#  ('Prolactin receptor', 'P16471'),
#  ('P16499', "Rod cGMP-specific 3',5'-cyclic phosphodiesterase subunit alpha"),
#  ('P16581', 'E-selectin'),
#  ('Fumarylacetoacetase', 'P16930'),
#  ('Zinc finger X-chromosomal protein', 'P17010'),
#  ('Zinc finger protein 12', 'P17014'),
#  ('Zinc finger protein 16', 'P17020'),
#  ('Zinc finger protein 17', 'P17021'),
#  ('P17022', 'Zinc finger protein 18'),
#  ('Zinc finger protein 19', 'P17023'),
#  ('Zinc finger protein 20', 'P17024'),
#  ('P17027', 'Zinc finger protein 23'),
#  ('Zinc finger protein 24', 'P17028'),
#  ('P17040', 'Zinc finger and SCAN domain-containing protein 20'),
#  ('Zinc finger protein 32', 'P17041'),
#  ('P17301', 'Integrin alpha-2'),
#  ('P17544', 'Cyclic AMP-dependent transcription factor ATF-7'),
#  ('P17643', '5,6-dihydroxyindole-2-carboxylic acid oxidase'),
#  ('ATP-dependent 6-phosphofructokinase, liver type', 'P17858'),
#  ('P17936', 'Insulin-like growth factor-binding protein 3'),
#  ('P18074',
#   'General transcription and DNA repair factor IIH helicase subunit XPD'),
#  ('P18084', 'Integrin beta-5'),
#  ('P18564', 'Integrin beta-6'),
#  ('DNA ligase 1', 'P18858'),
#  ('P19086', 'Guanine nucleotide-binding protein G(z) subunit alpha'),
#  ('P19087', 'Guanine nucleotide-binding protein G(t) subunit alpha-2'),
#  ('P19404', 'NADH dehydrogenase [ubiquinone] flavoprotein 2, mitochondrial'),
#  ('P20020', 'Plasma membrane calcium-transporting ATPase 1'),
#  ('Eukaryotic translation initiation factor 2 subunit 2', 'P20042'),
#  ('P20062', 'Transcobalamin-2'),
#  ('Cytochrome c oxidase subunit 5A, mitochondrial', 'P20674'),
#  ('P20701', 'Integrin alpha-L'),
#  ('Integrin alpha-X', 'P20702'),
#  ('Serine/threonine-protein kinase MAK', 'P20794'),
#  ("Inosine-5'-monophosphate dehydrogenase 1", 'P20839'),
#  ('P20849', 'Collagen alpha-1(IX) chain'),
#  ('P20908', 'Collagen alpha-1(V) chain'),
#  ('P21399', 'Cytoplasmic aconitate hydratase'),
#  ('Succinate dehydrogenase [ubiquinone] iron-sulfur subunit, mitochondrial',
#   'P21912'),
#  ('P21917', 'D(4) dopamine receptor'),
#  ('Methylmalonyl-CoA mutase, mitochondrial', 'P22033'),
#  ('Lactoperoxidase', 'P22079'),
#  ('Trifunctional purine biosynthetic protein adenosine-3', 'P22102'),
#  ('Nucleoside diphosphate kinase B', 'P22392'),
#  ('P22695', 'Cytochrome b-c1 complex subunit 2, mitochondrial'),
#  ('P22735', 'Protein-glutamine gamma-glutamyltransferase K'),
#  ('DNA repair protein complementing XP-A cells', 'P23025'),
#  ('AMP deaminase 1', 'P23109'),
#  ('P23219', 'Prostaglandin G/H synthase 1'),
#  ('P23229', 'Integrin alpha-6'),
#  ('P23276', 'Kell blood group glycoprotein'),
#  ('P23368', 'NAD-dependent malic enzyme, mitochondrial'),
#  ('Glycine receptor subunit alpha-2', 'P23416'),
#  ('P23458', 'Tyrosine-protein kinase JAK1'),
#  ('P23634', 'Plasma membrane calcium-transporting ATPase 4'),
#  ('Sodium-dependent noradrenaline transporter', 'P23975'),
#  ('P24278', 'Zinc finger and BTB domain-containing protein 25'),
#  ('P24723', 'Protein kinase C eta type'),
#  ('Transcriptional repressor protein YY1', 'P25490'),
#  ('P25713', 'Metallothionein-3'),
#  ('Rhombotin-2', 'P25791'),
#  ('Rhombotin-1', 'P25800'),
#  ('Integrin alpha-3', 'P26006'),
#  ('P26010', 'Integrin beta-7'),
#  ('Integrin beta-8', 'P26012'),
#  ('mRNA decay activator protein ZFP36', 'P26651'),
#  ('Activin receptor type-2A', 'P27037'),
#  ('P27694', 'Replication protein A 70 kDa DNA-binding subunit'),
#  ('DNA repair nuclease/redox regulator APEX1', 'P27695'),
#  ('P27815', "3',5'-cyclic-AMP phosphodiesterase 4A"),
#  ('NADH-ubiquinone oxidoreductase 75 kDa subunit, mitochondrial', 'P28331'),
#  ('P28340', 'DNA polymerase delta catalytic subunit'),
#  ('Myeloid zinc finger 1', 'P28698'),
#  ('P28715', 'DNA excision repair protein ERCC-5'),
#  ('General transcription factor IIE subunit 1', 'P29083'),
#  ('P29728', "2'-5'-oligoadenylate synthase 2"),
#  ('P29803',
#   'Pyruvate dehydrogenase E1 component subunit alpha, testis-specific form, mitochondrial'),
#  ('P29992', 'Guanine nucleotide-binding protein subunit alpha-11'),
#  ('Heme oxygenase 2', 'P30519'),
#  ('Sodium- and chloride-dependent GABA transporter 1', 'P30531'),
#  ('P30679', 'Guanine nucleotide-binding protein subunit alpha-15'),
#  ('P30876', 'DNA-directed RNA polymerase II subunit RPB2'),
#  ('S-adenosylmethionine synthase isoform type-2', 'P31153'),
#  ('P31327', 'Carbamoyl-phosphate synthase [ammonia], mitochondrial'),
#  ('Transcription factor HIVEP2', 'P31629'),
#  ('P31689', 'DnaJ homolog subfamily A member 1'),
#  ('RAC-beta serine/threonine-protein kinase', 'P31751'),
#  ('Cytochrome b-c1 complex subunit 1, mitochondrial', 'P31930'),
#  ('P32019', 'Type II inositol 1,4,5-trisphosphate 5-phosphatase'),
#  ('Glycerol kinase', 'P32189'),
#  ('P32754', '4-hydroxyphenylpyruvate dioxygenase'),
#  ('N-acetylgalactosamine-6-sulfatase', 'P34059'),
#  ('P35227', 'Polycomb group RING finger protein 2'),
#  ('Nitric oxide synthase, inducible', 'P35228'),
#  ('P35354', 'Prostaglandin G/H synthase 2'),
#  ('P35520', 'Cystathionine beta-synthase'),
#  ('P35625', 'Metalloproteinase inhibitor 3'),
#  ('RNA-binding protein FUS', 'P35637'),
#  ('P35913', "Rod cGMP-specific 3',5'-cyclic phosphodiesterase subunit beta"),
#  ('P35914', 'Hydroxymethylglutaryl-CoA lyase, mitochondrial'),
#  ('Dual specificity mitogen-activated protein kinase kinase 2', 'P36507'),
#  ('P36508', 'Zinc finger protein 76'),
#  ('P36639', 'Oxidized purine nucleoside triphosphate hydrolase'),
#  ('Serine/threonine-protein phosphatase PP1-gamma catalytic subunit',
#   'P36873'),
#  ('P36894', 'Bone morphogenetic protein receptor type-1A'),
#  ('Activin receptor type-1B', 'P36896'),
#  ('TGF-beta receptor type-1', 'P36897'),
#  ('GMP reductase 1', 'P36959'),
#  ('Activin receptor type-1-like', 'P37023'),
#  ('TGF-beta receptor type-2', 'P37173'),
#  ('P37268', 'Squalene synthase'),
#  ('P38405', 'Guanine nucleotide-binding protein G(olf) subunit alpha'),
#  ('Integrin alpha-E', 'P38570'),
#  ('P38936', 'Cyclin-dependent kinase inhibitor 1'),
#  ('P39060', 'Collagen alpha-1(XVIII) chain'),
#  ('Adenylate cyclase type 8', 'P40145'),
#  ('P40616', 'ADP-ribosylation factor-like protein 1'),
#  ('P41182', 'B-cell lymphoma 6 protein'),
#  ('P41240', 'Tyrosine-protein kinase CSK'),
#  ('Protein kinase C iota type', 'P41743'),
#  ('Tyrosine-protein kinase Tec', 'P42680'),
#  ('Probable helicase with zinc finger domain', 'P42694'),
#  ('Excitatory amino acid transporter 1', 'P43003'),
#  ('Excitatory amino acid transporter 2', 'P43004'),
#  ('Excitatory amino acid transporter 3', 'P43005'),
#  ('P45381', 'Aspartoacylase'),
#  ('P46063', 'ATP-dependent DNA helicase Q1'),
#  ('Transcriptional regulator ATRX', 'P46100'),
#  ('P46459', 'Vesicle-fusing ATPase'),
#  ('P46736', 'Lys-63-specific deubiquitinase BRCC36'),
#  ('Dolichyl-diphosphooligosaccharide--protein glycosyltransferase subunit STT3A',
#   'P46977'),
#  ('mRNA decay activator protein ZFP36L2', 'P47974'),
#  ('P47985', 'Cytochrome b-c1 complex subunit Rieske, mitochondrial'),
#  ('Iron-responsive element-binding protein 2', 'P48200'),
#  ('P48454',
#   'Serine/threonine-protein phosphatase 2B catalytic subunit gamma isoform'),
#  ('P48664', 'Excitatory amino acid transporter 4'),
#  ('Tryptophan 2,3-dioxygenase', 'P48775'),
#  ('Paxillin', 'P49023'),
#  ('Protein-glutamine gamma-glutamyltransferase 4', 'P49221'),
#  ('Protein ERGIC-53', 'P49257'),
#  ('P49447', 'Transmembrane ascorbate-dependent reductase CYB561'),
#  ('P49589', 'Cysteine--tRNA ligase, cytoplasmic'),
#  ('Protein phosphatase 1F', 'P49593'),
#  ('Alpha-mannosidase 2x', 'P49641'),
#  ('P49643', 'DNA primase large subunit'),
#  ('P49736', 'DNA replication licensing factor MCM2'),
#  ('Vacuolar protein sorting-associated protein 41 homolog', 'P49754'),
#  ('P49790', 'Nuclear pore complex protein Nup153'),
#  ('P49792', 'E3 SUMO-protein ligase RanBP2'),
#  ('P49821', 'NADH dehydrogenase [ubiquinone] flavoprotein 1, mitochondrial'),
#  ("Cytosolic purine 5'-nucleotidase", 'P49902'),
#  ('Selenide, water dikinase 1', 'P49903'),
#  ('Zinc finger protein 165', 'P49910'),
#  ('5-formyltetrahydrofolate cyclo-ligase', 'P49914'),
#  ('P50148', 'Guanine nucleotide-binding protein G(q) subunit alpha'),
#  ('P50458', 'LIM/homeobox protein Lhx2'),
#  ('Cysteine and glycine-rich protein 3', 'P50461'),
#  ('P50479', 'PDZ and LIM domain protein 4'),
#  ('Methionine aminopeptidase 2', 'P50579'),
#  ('P51160',
#   "Cone cGMP-specific 3',5'-cyclic phosphodiesterase subunit alpha'"),
#  ('DNA replication ATP-dependent helicase/nuclease DNA2', 'P51530'),
#  ('P51688', 'N-sulphoglucosamine sulphohydrolase'),
#  ('Arylsulfatase L', 'P51690'),
#  ('P51800', 'Chloride channel protein ClC-Ka'),
#  ('Chloride channel protein ClC-Kb', 'P51801'),
#  ('Cytoplasmic tyrosine-protein kinase BMX', 'P51813'),
#  ('P51814', 'Zinc finger protein 41'),
#  ('Adenylate cyclase type 7', 'P51828'),
#  ('P51854', 'Transketolase-like protein 1'),
#  ('P51955', 'Serine/threonine-protein kinase Nek2'),
#  ('P51956', 'Serine/threonine-protein kinase Nek3'),
#  ('Diacylglycerol kinase epsilon', 'P52429'),
#  ('Arf-GAP domain and FG repeat-containing protein 1', 'P52594'),
#  ('P52735', 'Guanine nucleotide exchange factor VAV2'),
#  ('P52736', 'Zinc finger protein 133'),
#  ('P52738', 'Zinc finger protein 140'),
#  ('P52739', 'Zinc finger protein 131'),
#  ('Zinc finger protein 135', 'P52742'),
#  ('P52744', 'Zinc finger protein 138'),
#  ('Zinc finger protein 143', 'P52747'),
#  ('P52756', 'RNA-binding protein 5'),
#  ('Beta-chimaerin', 'P52757'),
#  ('P52824', 'Diacylglycerol kinase theta'),
#  ('Thimet oligopeptidase', 'P52888'),
#  ('Serine/threonine-protein phosphatase 5', 'P53041'),
#  ('Cytosolic Fe-S cluster assembly factor NUBP1', 'P53384'),
#  ('P53396', 'ATP-citrate synthase'),
#  ('Methionine aminopeptidase 1', 'P53582'),
#  ('LIM domain kinase 1', 'P53667'),
#  ('P53671', 'LIM domain kinase 2'),
#  ('Holocytochrome c-type synthase', 'P53701'),
#  ('Integrin alpha-8', 'P53708'),
#  ('E3 ubiquitin-protein ligase TTC3', 'P53804'),
#  ('Voltage-dependent calcium channel subunit alpha-2/delta-1', 'P54289'),
#  ("5'-AMP-activated protein kinase catalytic subunit alpha-2", 'P54646'),
#  ('P54707', 'Potassium-transporting ATPase alpha chain 2'),
#  ('P54750',
#   "Dual specificity calcium/calmodulin-dependent 3',5'-cyclic nucleotide phosphodiesterase 1A"),
#  ('P55039', 'Developmentally-regulated GTP-binding protein 2'),
#  ('Protein AF-10', 'P55197'),
#  ('P55198', 'Protein AF-17'),
#  ('P55201', 'Peregrin'),
#  ('Adenosine kinase', 'P55263'),
#  ('P55265', 'Double-stranded RNA-specific adenosine deaminase'),
#  ('Integrin alpha-1', 'P56199'),
#  ('Myc-associated zinc finger protein', 'P56270'),
#  ('P57071', 'PR domain zinc finger protein 15'),
#  ('Sodium/calcium exchanger 3', 'P57103'),
#  ('Krueppel-like factor 3', 'P57682'),
#  ('P58335', 'Anthrax toxin receptor 2'),
#  ('P58397',
#   'A disintegrin and metalloproteinase with thrombospondin motifs 12'),
#  ('Neurexin-1-beta', 'P58400'),
#  ('Neurexin-2-beta', 'P58401'),
#  ('P59817', 'Zinc finger protein 280A'),
#  ('Zinc finger protein 445', 'P59923'),
#  ('Serine/threonine-protein phosphatase 4 catalytic subunit', 'P60510'),
#  ('P61371', 'Insulin gene enhancer protein ISL-1'),
#  ('Large ribosomal subunit protein eL43', 'P61513'),
#  ('10 kDa heat shock protein, mitochondrial', 'P61604'),
#  ('Large ribosomal subunit protein eL37', 'P61927'),
#  ('LIM domain transcription factor LMO4', 'P61968'),
#  ('Ubiquitin carboxyl-terminal hydrolase 46', 'P62068'),
#  ('P62140', 'Serine/threonine-protein phosphatase PP1-beta catalytic subunit'),
#  ('P62699', 'Protein yippee-like 5'),
#  ('Serine/threonine-protein phosphatase 2A catalytic subunit beta isoform',
#   'P62714'),
#  ('Ubiquitin-ribosomal protein eS31 fusion protein', 'P62979'),
#  ('P63092',
#   'Guanine nucleotide-binding protein G(s) subunit alpha isoforms short'),
#  ('Serine/threonine-protein phosphatase 2A catalytic subunit alpha isoform',
#   'P67775'),
#  ('P67870', 'Casein kinase II subunit beta'),
#  ('P68366', 'Tubulin alpha-4A chain'),
#  ('P68371', 'Tubulin beta-4B chain'),
#  ('P68871', 'Hemoglobin subunit beta'),
#  ('Hemoglobin subunit gamma-1', 'P69891'),
#  ('P69892', 'Hemoglobin subunit gamma-2'),
#  ('Reelin', 'P78509'),
#  ('Disintegrin and metalloproteinase domain-containing protein 17', 'P78536'),
#  ('P78549', 'Endonuclease III-like protein 1'),
#  ('Double-stranded RNA-specific editase 1', 'P78563'),
#  ('Proline-rich protein 3', 'P79522'),
#  ('Metallothionein-1H', 'P80294'),
#  ('Metallothionein-1X', 'P80297'),
#  ('4-aminobutyrate aminotransferase, mitochondrial', 'P80404'),
#  ('Dermcidin', 'P81605'),
#  ('P86452', 'Zinc finger BED domain-containing protein 6'),
#  ('Mucin-5AC', 'P98088'),
#  ('Zinc finger X-linked protein ZXDA', 'P98168'),
#  ('P98170', 'E3 ubiquitin-protein ligase XIAP'),
#  ('P98174', 'FYVE, RhoGEF and PH domain-containing protein 1'),
#  ('RNA-binding protein 10', 'P98175'),
#  ('Calcium-transporting ATPase type 2C member 1', 'P98194'),
#  ('Cytochrome c', 'P99999'),
#  ('S-adenosylmethionine synthase isoform type-1', 'Q00266'),
#  ('Q00994', 'Protein BEX3'),
#  ('Q01064',
#   "Dual specificity calcium/calmodulin-dependent 3',5'-cyclic nucleotide phosphodiesterase 1B"),
#  ('Q01081', 'Splicing factor U2AF 35 kDa subunit'),
#  ('Insulinoma-associated protein 1', 'Q01101'),
#  ('Q01432', 'AMP deaminase 3'),
#  ('Q01433', 'AMP deaminase 2'),
#  ('Q01668', 'Voltage-dependent L-type calcium channel subunit alpha-1D'),
#  ('Exosome complex component 10', 'Q01780'),
#  ('ATP-dependent 6-phosphofructokinase, platelet type', 'Q01813'),
#  ('Plasma membrane calcium-transporting ATPase 2', 'Q01814'),
#  ('RNA-binding protein EWS', 'Q01844'),
#  ('Q01954', 'Zinc finger protein basonuclin-1'),
#  ('Sodium-dependent dopamine transporter', 'Q01959'),
#  ('Tyrosine-protein kinase transmembrane receptor ROR2', 'Q01974'),
#  ('Q02086', 'Transcription factor Sp2'),
#  ('Q02153', 'Guanylate cyclase soluble subunit beta-1'),
#  ('Protein kinase C epsilon type', 'Q02156'),
#  ('Q02218', '2-oxoglutarate dehydrogenase complex component E1'),
#  ('Transcription factor Sp4', 'Q02446'),
#  ('Q02447', 'Transcription factor Sp3'),
#  ('DNA topoisomerase 2-beta', 'Q02880'),
#  ('Q02930', 'Cyclic AMP-responsive element-binding protein 5'),
#  ('Histone-lysine N-methyltransferase MECOM', 'Q03112'),
#  ('Q03113', 'Guanine nucleotide-binding protein subunit alpha-12'),
#  ('Aminoacylase-1', 'Q03154'),
#  ('6-pyruvoyl tetrahydrobiopterin synthase', 'Q03393'),
#  ('Q03518', 'Antigen peptide transporter 1'),
#  ('Antigen peptide transporter 2', 'Q03519'),
#  ('Collagen alpha-1(X) chain', 'Q03692'),
#  ('Q03721', 'Voltage-gated potassium channel KCNC4'),
#  ('Q03923', 'Zinc finger protein 85'),
#  ('Q04609', 'Glutamate carboxypeptidase 2'),
#  ('Q04759', 'Protein kinase C theta type'),
#  ('Activin receptor type-1', 'Q04771'),
#  ('Q05086', 'Ubiquitin-protein ligase E3A'),
#  ('Q05215', 'Early growth response protein 4'),
#  ('Protein kinase C zeta type', 'Q05513'),
#  ('Zinc finger and BTB domain-containing protein 16', 'Q05516'),
#  ('Q05655', 'Protein kinase C delta type'),
#  ('Q05823', '2-5A-dependent ribonuclease'),
#  ('Folylpolyglutamate synthase, mitochondrial', 'Q05932'),
#  ('Q06187', 'Tyrosine-protein kinase BTK'),
#  ('Q06203', 'Amidophosphoribosyltransferase'),
#  ('Q06455', 'Protein CBFA2T1'),
#  ('Q06587', 'E3 ubiquitin-protein ligase RING1'),
#  ('Q06730', 'Zinc finger protein 33A'),
#  ('Q06889', 'Early growth response protein 3'),
#  ('Q07343', "3',5'-cyclic-AMP phosphodiesterase 4B"),
#  ('Q07352', 'mRNA decay activator protein ZFP36L1'),
#  ('Activated CDC42 kinase 1', 'Q07912'),
#  ('Q08211', 'ATP-dependent RNA helicase A'),
#  ('Q08345', 'Epithelial discoidin domain-containing receptor 1'),
#  ('Q08493', "3',5'-cyclic-AMP phosphodiesterase 4C"),
#  ('Q08499', "3',5'-cyclic-AMP phosphodiesterase 4D"),
#  ("Pseudouridine-5'-phosphatase", 'Q08623'),
#  ('Q08828', 'Adenylate cyclase type 1'),
#  ('Q08881', 'Tyrosine-protein kinase ITK/TSK'),
#  ('Q08AG5', 'Zinc finger protein 844'),
#  ('Q08AH1', 'Acyl-coenzyme A synthetase ACSM1, mitochondrial'),
#  ('Q08AH3', 'Acyl-coenzyme A synthetase ACSM2A, mitochondrial'),
#  ('Myotonin-protein kinase', 'Q09013'),
#  ('Zinc finger protein 415', 'Q09FC8'),
#  ('Mitochondrial-processing peptidase subunit alpha', 'Q10713'),
#  ('Q12791', 'Calcium-activated potassium channel subunit alpha-1'),
#  ('A-kinase anchor protein 13', 'Q12802'),
#  ('Q12830', 'Nucleosome-remodeling factor subunit BPTF'),
#  ('Dihydropyrimidine dehydrogenase [NADP(+)]', 'Q12882'),
#  ('Q12899', 'Tripartite motif-containing protein 26'),
#  ('Vesicular integral-membrane protein VIP36', 'Q12907'),
#  ('Q13064', 'Probable E3 ubiquitin-protein ligase makorin-3'),
#  ('Q13075', 'Baculoviral IAP repeat-containing protein 1'),
#  ('Q13085', 'Acetyl-CoA carboxylase 1'),
#  ('Q13105', 'Zinc finger and BTB domain-containing protein 17'),
#  ('Q13107', 'Ubiquitin carboxyl-terminal hydrolase 4'),
#  ('Q13118', 'Krueppel-like factor 10'),
#  ('Q13127', 'RE1-silencing transcription factor'),
#  ('Zinc finger protein Rlf', 'Q13129'),
#  ("5'-AMP-activated protein kinase catalytic subunit alpha-1", 'Q13131'),
#  ('Q13137', 'Calcium-binding and coiled-coil domain-containing protein 2'),
#  ('Dual specificity mitogen-activated protein kinase kinase 5', 'Q13163'),
#  ('Q13232', 'Nucleoside diphosphate kinase 3'),
#  ('Metastasis-associated protein MTA1', 'Q13330'),
#  ('Q13342', 'Nuclear body protein SP140'),
#  ('Integrin alpha-D', 'Q13349'),
#  ('Q13351', 'Krueppel-like factor 1'),
#  ('Q13360', 'Zinc finger protein 177'),
#  ("cGMP-inhibited 3',5'-cyclic phosphodiesterase 3B", 'Q13370'),
#  ('Q13394', 'Putative nucleotidyltransferase MAB21L1'),
#  ('Zinc finger protein 211', 'Q13398'),
#  ('Q13415', 'Origin recognition complex subunit 1'),
#  ('Q13422', 'DNA-binding protein Ikaros'),
#  ('Disintegrin and metalloproteinase domain-containing protein 9', 'Q13443'),
#  ('Q13444', 'Disintegrin and metalloproteinase domain-containing protein 15'),
#  ('Q13459', 'Unconventional myosin-IXb'),
#  ('Q13464', 'Rho-associated protein kinase 1'),
#  ('Mothers against decapentaplegic homolog 4', 'Q13485'),
#  ('Baculoviral IAP repeat-containing protein 3', 'Q13489'),
#  ('Short transient receptor potential channel 3', 'Q13507'),
#  ('Q13509', 'Tubulin beta-3 chain'),
#  ('Q13574', 'Diacylglycerol kinase zeta'),
#  ('Phosphatidylinositol-3,5-bisphosphate 3-phosphatase MTMR3', 'Q13615'),
#  ('Q13642', 'Four and a half LIM domains protein 1'),
#  ('Four and a half LIM domains protein 3', 'Q13643'),
#  ('Integrin alpha-7', 'Q13683'),
#  ('Voltage-dependent L-type calcium channel subunit alpha-1S', 'Q13698'),
#  ('43 kDa receptor-associated protein of the synapse', 'Q13702'),
#  ('Q13705', 'Activin receptor type-2B'),
#  ('Q13733', 'Sodium/potassium-transporting ATPase subunit alpha-4'),
#  ('Integrin alpha-9', 'Q13797'),
#  ('Q13873', 'Bone morphogenetic protein receptor type-2'),
#  ('Tubulin beta-2A chain', 'Q13885'),
#  ('Krueppel-like factor 9', 'Q13886'),
#  ('Krueppel-like factor 5', 'Q13887'),
#  ('General transcription factor IIH subunit 3', 'Q13889'),
#  ('Q13907', 'Isopentenyl-diphosphate Delta-isomerase 1'),
#  ('Q13936', 'Voltage-dependent L-type calcium channel subunit alpha-1C'),
#  ("High affinity 3',5'-cyclic-AMP phosphodiesterase 7A", 'Q13946'),
#  ('Voltage-gated potassium channel KCNC3', 'Q14003'),
#  ('Q14119', 'Vascular endothelial zinc finger 1'),
#  ('Q14123',
#   "Dual specificity calcium/calmodulin-dependent 3',5'-cyclic nucleotide phosphodiesterase 1C"),
#  ('ARF GTPase-activating protein GIT2', 'Q14161'),
#  ('Double C2-like domain-containing protein alpha', 'Q14183'),
#  ('Q14192', 'Four and a half LIM domains protein 2'),
#  ('Q14258', 'E3 ubiquitin/ISG15 ligase TRIM25'),
#  ('Peptidyl-prolyl cis-trans isomerase FKBP8', 'Q14318'),
#  ('Guanine nucleotide-binding protein subunit alpha-13', 'Q14344'),
#  ('Q14406', 'Chorionic somatomammotropin hormone-like 1'),
#  ("cGMP-inhibited 3',5'-cyclic phosphodiesterase 3A", 'Q14432'),
#  ('Q14526', 'Hypermethylated in cancer 1 protein'),
#  ('Q14584', 'Zinc finger protein 266'),
#  ('Q14585', 'Zinc finger protein 345'),
#  ('Q14587', 'Zinc finger protein 268'),
#  ('Q14592', 'Zinc finger protein 460'),
#  ('Ras GTPase-activating protein 3', 'Q14644'),
#  ('Q14679', 'Tubulin monoglutamylase TTLL4'),
#  ('LIM and SH3 domain protein 1', 'Q14847'),
#  ('Q14872', 'Metal regulatory transcription factor 1'),
#  ('Q14896', 'Myosin-binding protein C, cardiac-type'),
#  ('Zinc finger protein 169', 'Q14929'),
#  ('E3 ubiquitin-protein ligase SHPRH', 'Q149N8'),
#  ('Q14CN2', 'Calcium-activated chloride channel regulator 4'),
#  ('Receptor-transporting protein 5', 'Q14D33'),
#  ('Polycomb protein SUZ12', 'Q15022'),
#  ('Arf-GAP with coiled-coil, ANK repeat and PH domain-containing protein 1',
#   'Q15027'),
#  ('Q15057',
#   'Arf-GAP with coiled-coil, ANK repeat and PH domain-containing protein 2'),
#  ('Periostin', 'Q15063'),
#  ('Q15139', 'Serine/threonine-protein kinase D1'),
#  ('Q15165', 'Serum paraoxonase/arylesterase 2'),
#  ('Serum paraoxonase/lactonase 3', 'Q15166'),
#  ('Q15257', 'Serine/threonine-protein phosphatase 2A activator'),
#  ('Ras GTPase-activating protein 2', 'Q15283'),
#  ('Q15485', 'Ficolin-2'),
#  ('Q15569', 'Dual specificity testis-specific protein kinase 1'),
#  ('Q15649', 'Zinc finger HIT domain-containing protein 3'),
#  ('Q15652',
#   'Probable JmjC domain-containing histone demethylation protein 2C'),
#  ('Thyroid receptor-interacting protein 6', 'Q15654'),
#  ('U2 small nuclear ribonucleoprotein auxiliary factor 35 kDa subunit-related protein 2',
#   'Q15696'),
#  ('Q15697', 'Zinc finger protein 174'),
#  ('Myosin light chain kinase, smooth muscle', 'Q15746'),
#  ('Neutral amino acid transporter B(0)', 'Q15758'),
#  ('Q15776', 'Zinc finger protein with KRAB and SCAN domains 8'),
#  ('Q15796', 'Mothers against decapentaplegic homolog 2'),
#  ('Q15797', 'Mothers against decapentaplegic homolog 1'),
#  ('Q15818', 'Neuronal pentraxin-1'),
#  ('Q15915', 'Zinc finger protein ZIC 1'),
#  ('Zinc finger and BTB domain-containing protein 6', 'Q15916'),
#  ('Q15928', 'Zinc finger protein 141'),
#  ('Zyxin', 'Q15942'),
#  ('Q15973', 'Zinc finger protein 124'),
#  ('Q16134',
#   'Electron transfer flavoprotein-ubiquinone oxidoreductase, mitochondrial'),
#  ('Q16342', 'Programmed cell death protein 2'),
#  ('Exostosin-1', 'Q16394'),
#  ('Q16518', 'Retinoid isomerohydrolase'),
#  ('Q16527', 'Cysteine and glycine-rich protein 2'),
#  ('Zinc finger protein 74', 'Q16587'),
#  ('Zinc finger protein 239', 'Q16600'),
#  ('Bcl-2 homologous antagonist/killer', 'Q16611'),
#  ('Zinc finger and SCAN domain-containing protein 26', 'Q16670'),
#  ('Anti-Muellerian hormone type-2 receptor', 'Q16671'),
#  ('Q16706', 'Alpha-mannosidase 2'),
#  ('Q16720', 'Plasma membrane calcium-transporting ATPase 3'),
#  ('Q16760', 'Diacylglycerol kinase delta'),
#  ('Q16775', 'Hydroxyacylglutathione hydrolase, mitochondrial'),
#  ('NADP-dependent malic enzyme, mitochondrial', 'Q16798'),
#  ('Q16851', 'UTP--glucose-1-phosphate uridylyltransferase'),
#  ('Q17R98', 'Zinc finger protein 827'),
#  ('Q17RB8', 'LON peptidase N-terminal domain and RING finger protein 1'),
#  ('Cytoplasmic polyadenylation element-binding protein 4', 'Q17RY0'),
#  ('LON peptidase N-terminal domain and RING finger protein 2', 'Q1L5Z9'),
#  ('Q2KHM9', 'Protein moonraker'),
#  ('Q2M1K9', 'Zinc finger protein 423'),
#  ('Q2QGD7', 'Zinc finger protein ZXDC'),
#  ('Chromosome-associated kinesin KIF4B', 'Q2VIQ3'),
#  ('Q32MQ0', 'Zinc finger protein 750'),
#  ('Leucine-rich repeat serine/threonine-protein kinase 1', 'Q38SD2'),
#  ('Zinc finger protein 829', 'Q3KNS6'),
#  ('Polycomb group RING finger protein 3', 'Q3KNV8'),
#  ('Q3KQV3', 'Zinc finger protein 792'),
#  ('Q3KRA9', 'Alpha-ketoglutarate-dependent dioxygenase alkB homolog 6'),
#  ('Q3LXA3', 'Triokinase/FMN cyclase'),
#  ('tRNA pseudouridine synthase Pus10', 'Q3MIT2'),
#  ('Q3MJ62', 'Zinc finger and SCAN domain-containing protein 23'),
#  ('Probable tubulin polyglutamylase TTLL9', 'Q3SXZ7'),
#  ('Transcription factor Sp6', 'Q3SY56'),
#  ('Tubulin beta-8 chain', 'Q3ZCM7'),
#  ('Q495C1', 'Probable E3 SUMO-protein ligase RNF212'),
#  ('Membrane metallo-endopeptidase-like 1', 'Q495T6'),
#  ('Q49A17', 'Polypeptide N-acetylgalactosaminyltransferase-like 6'),
#  ('Q4FZB7', 'Histone-lysine N-methyltransferase KMT5B'),
#  ('Q4KMQ2', 'Anoctamin-6'),
#  ('Q4VC12', 'Putative protein MSS51 homolog, mitochondrial'),
#  ('Q4VC44', 'FLYWCH-type zinc finger-containing protein 1'),
#  ('Q4VNC1', 'Probable cation-transporting ATPase 13A4'),
#  ('Q504Q3', 'PAN2-PAN3 deadenylation complex catalytic subunit PAN2'),
#  ('Q52LW3', 'Rho GTPase-activating protein 29'),
#  ('Q53FD0', 'Zinc finger C2HC domain-containing protein 1C'),
#  ('Q53FZ2', 'Acyl-coenzyme A synthetase ACSM3, mitochondrial'),
#  ('PDZ and LIM domain protein 3', 'Q53GG5'),
#  ('TATA box-binding protein-associated factor RNA polymerase I subunit B',
#   'Q53T94'),
#  ('Q53TN4', 'Plasma membrane ascorbate-dependent reductase CYBRD1'),
#  ('N-acetyltransferase ESCO2', 'Q56NI9'),
#  ('PAN2-PAN3 deadenylation complex subunit PAN3', 'Q58A45'),
#  ('Serine/threonine-protein kinase TNNI3K', 'Q59H18'),
#  ('Q5BKZ1', 'DBIRD complex subunit ZNF326'),
#  ('Endoribonuclease ZC3H12A', 'Q5D1E8'),
#  ('Arylsulfatase I', 'Q5FYB1'),
#  ('Q5H8C1', 'FRAS1-related extracellular matrix protein 1'),
#  ('Q5H9J7', 'Protein BEX5'),
#  ('FYVE, RhoGEF and PH domain-containing protein 3', 'Q5JSP0'),
#  ('Zinc-regulated GTPase metalloprotein activator 1C', 'Q5JTY5'),
#  ('Q5JWF2',
#   'Guanine nucleotide-binding protein G(s) subunit alpha isoforms XLas'),
#  ('Q5KSL6', 'Diacylglycerol kinase kappa'),
#  ('Q5KU26', 'Collectin-12'),
#  ('Q5M7Z0', 'E3 ubiquitin-protein ligase RNFT1'),
#  ('Ectonucleoside triphosphate diphosphohydrolase 8', 'Q5MY95'),
#  ('Receptor-transporting protein 2', 'Q5QGT7'),
#  ('Alkaline ceramidase 2', 'Q5QJU3'),
#  ('Q5SGD2', 'Protein phosphatase 1L'),
#  ('Q5SRE7', 'Phytanoyl-CoA dioxygenase domain-containing protein 1'),
#  ('Q5SZK8', 'FRAS1-related extracellular matrix protein 2'),
#  ('Q5T197', 'E3 ubiquitin-protein ligase DCST1'),
#  ('Transcription factor HIVEP3', 'Q5T1R4'),
#  ('Probable ATP-dependent RNA helicase DDX59', 'Q5T1V6'),
#  ('Q5T200', 'Zinc finger CCCH domain-containing protein 13'),
#  ('All trans-polyprenyl-diphosphate synthase PDSS1', 'Q5T2R2'),
#  ('Protrudin', 'Q5T4F4'),
#  ('Q5T619', 'Zinc finger protein 648'),
#  ('Q5T6S3', 'PHD finger protein 19'),
#  ('Q5T7W0', 'Zinc finger protein 618'),
#  ("Small RNA 2'-O-methyltransferase", 'Q5T8I9'),
#  ('E3 ubiquitin-protein ligase RNF187', 'Q5TA31'),
#  ('Q5TD97', 'Four and a half LIM domains protein 5'),
#  ('RNA-binding E3 ubiquitin-protein ligase MEX3C', 'Q5U5Q3'),
#  ('Q5VST9', 'Obscurin'),
#  ('E3 ubiquitin-protein ligase RNF220', 'Q5VTB9'),
#  ('Zinc finger protein Gfi-1b', 'Q5VTD9'),
#  ('E3 ubiquitin-protein ligase BRE1A', 'Q5VTR2'),
#  ('Threonylcarbamoyladenosine tRNA methylthiotransferase', 'Q5VV42'),
#  ('Deubiquitinase MYSM1', 'Q5VVJ2'),
#  ('Q5VVQ6', 'Ubiquitin thioesterase OTU1'),
#  ('Transcription initiation factor TFIID subunit 3', 'Q5VWG9'),
#  ('Q5VZF2', 'Muscleblind-like protein 2'),
#  ('ORC ubiquitin ligase 1', 'Q5W0B1'),
#  ('Q5XG87', 'Terminal nucleotidyltransferase 4A'),
#  ('Q5XPI4', 'E3 ubiquitin-protein ligase RNF123'),
#  ('Q5XXA6', 'Anoctamin-1'),
#  ('Teashirt homolog 3', 'Q63HK5'),
#  ('E3 ubiquitin-protein ligase RNF213', 'Q63HN8'),
#  ('Q63HR2', 'Tensin-2'),
#  ('Metalloreductase STEAP3', 'Q658P3'),
#  ('DDB1- and CUL4-associated factor 15', 'Q66K64'),
#  ('Q66K89', 'Transcription factor E4F1'),
#  ('Q687X5', 'Metalloreductase STEAP4'),
#  ('Q68CK6', 'Acyl-coenzyme A synthetase ACSM2B, mitochondrial'),
#  ('AT-rich interactive domain-containing protein 2', 'Q68CP9'),
#  ('Q68D91', 'Acyl-coenzyme A thioesterase MBLAC2'),
#  ('Zinc finger FYVE domain-containing protein 26', 'Q68DK2'),
#  ('Q68DV7', 'E3 ubiquitin-protein ligase RNF43'),
#  ('Q68EA5', 'Zinc finger protein 57'),
#  ('Q68G74', 'LIM/homeobox protein Lhx8'),
#  ('Lysine-specific demethylase 4D', 'Q6B0I6'),
#  ('N6-Methyl-AMP deaminase', 'Q6DHV7'),
#  ('Q6DJT9', 'Zinc finger protein PLAG1'),
#  ('Zinc finger protein 470', 'Q6ECI4'),
#  ('Q6EMB2', 'Tubulin polyglutamylase TTLL5'),
#  ('Protein-lysine N-trimethyltransferase SMYD5', 'Q6GMV2'),
#  ('Q6GTS8', 'N-fatty-acyl-amino acid synthase/hydrolase PM20D1'),
#  ('Q6H8Q1', 'Actin-binding LIM protein 2'),
#  ('Q6IE81', 'Protein Jade-1'),
#  ('U11/U12 small nuclear ribonucleoprotein 48 kDa protein', 'Q6IEG0'),
#  ('Caprin-2', 'Q6IMN6'),
#  ('Q6IS24', 'Polypeptide N-acetylgalactosaminyltransferase 17'),
#  ("2',5'-phosphodiesterase 12", 'Q6L8Q7'),
#  ('Q6MZP7', 'Protein lin-54 homolog'),
#  ('Q6N043', 'Zinc finger protein 280D'),
#  ('Q6NUN0', 'Acyl-coenzyme A synthetase ACSM5, mitochondrial'),
#  ('Q6NUN9', 'Zinc finger protein 746'),
#  ('Q6NX45', 'Zinc finger protein 774'),
#  ('Q6NZ36', 'Fanconi anemia core complex-associated protein 20'),
#  ('Q6P158', 'Putative ATP-dependent RNA helicase DHX57'),
#  ('Zinc finger protein 1 homolog', 'Q6P2D0'),
#  ('Q6P461', 'Acyl-coenzyme A synthetase ACSM6, mitochondrial'),
#  ('Ferredoxin-2, mitochondrial', 'Q6P4F2'),
#  ('Q6P587', 'Oxaloacetate tautomerase FAHD1, mitochondrial'),
#  ('Zinc transporter ZIP4', 'Q6P5W5'),
#  ('RNA demethylase ALKBH5', 'Q6P6C2'),
#  ('Polypeptide N-acetylgalactosaminyltransferase 18', 'Q6P9A2'),
#  ('Q6P9G9', 'Zinc finger protein 449'),
#  ('E3 ubiquitin-protein ligase RFWD3', 'Q6PCD5'),
#  ('Glucose 1,6-bisphosphate synthase', 'Q6PCE3'),
#  ('Q6PEY2', 'Tubulin alpha-3E chain'),
#  ('Poly(A) RNA polymerase GLD2', 'Q6PIY7'),
#  ('Q6PJI9', 'GATOR2 complex protein WDR59'),
#  ('DNA cross-link repair 1A protein', 'Q6PJP8'),
#  ('Zinc finger CCCH domain-containing protein 14', 'Q6PJT7'),
#  ('Q6S9Z5', 'Zinc finger protein 474'),
#  ('Q6U7Q0', 'Zinc finger protein 322'),
#  ('Methionine aminopeptidase 1D, mitochondrial', 'Q6UB28'),
#  ('Regenerating islet-derived protein 3-gamma', 'Q6UW15'),
#  ('E3 ubiquitin-protein ligase LRSAM1', 'Q6UWE0'),
#  ('Q6UWR7', 'Glycerophosphocholine cholinephosphodiesterase ENPP6'),
#  ('Q6UWY0', 'Arylsulfatase K'),
#  ('Kinase suppressor of Ras 2', 'Q6VAB6'),
#  ('Q6VVB1', 'E3 ubiquitin-protein ligase NHLRC1'),
#  ('Nicotinate phosphoribosyltransferase', 'Q6XQN6'),
#  ('Q6ZMS7', 'Zinc finger protein 783'),
#  ('Q6ZMT1', 'SH3 and cysteine-rich domain-containing protein 2'),
#  ('Mitogen-activated protein kinase kinase kinase 15', 'Q6ZN16'),
#  ('Q6ZN18', 'Zinc finger protein AEBP2'),
#  ('Q6ZN30', 'Zinc finger protein basonuclin-2'),
#  ('Zinc finger protein 574', 'Q6ZN55'),
#  ('Q6ZN57', 'Zinc finger protein ZFP2'),
#  ('E3 ubiquitin-protein ligase Arkadia', 'Q6ZNA4'),
#  ('RUN and FYVE domain-containing protein 4', 'Q6ZNE9'),
#  ('Q6ZNG0', 'Zinc finger protein 620'),
#  ('Zinc finger protein 497', 'Q6ZNH5'),
#  ('Q6ZNL6', 'FYVE, RhoGEF and PH domain-containing protein 5'),
#  ('Indoleamine 2,3-dioxygenase 2', 'Q6ZQW0'),
#  ('Q6ZS10', 'C-type lectin domain family 17, member A'),
#  ('Zinc finger and BTB domain-containing protein 49', 'Q6ZSB9'),
#  ('Q6ZSZ5', 'Rho guanine nucleotide exchange factor 18'),
#  ('Q6ZSZ6', 'Teashirt homolog 1'),
#  ('Q6ZT21', 'Transmembrane protein with metallophosphoesterase domain'),
#  ('Q6ZT98', 'Tubulin polyglutamylase TTLL7'),
#  ('FYVE, RhoGEF and PH domain-containing protein 6', 'Q6ZV73'),
#  ('PH domain leucine-rich repeat-containing protein phosphatase 2', 'Q6ZVD8'),
#  ('Q6ZVK8', '8-oxo-dGDP phosphatase NUDT18'),
#  ('Q6ZWH5', 'Serine/threonine-protein kinase Nek10'),
#  ('MOB kinase activator 2', 'Q70IA6'),
#  ('MOB kinase activator 3C', 'Q70IA8'),
#  ('Protein unc-13 homolog D', 'Q70J99'),
#  ('Chondroitin sulfate synthase 3', 'Q70JA7'),
#  ('Q70YC5', 'Protein ZNF365'),
#  ('Q71U36', 'Tubulin alpha-1A chain'),
#  ('Ribosomal protein eS27-like', 'Q71UM5'),
#  ('Q75N03', 'E3 ubiquitin-protein ligase Hakai'),
#  ('Q76L83', 'Putative Polycomb group protein ASXL2'),
#  ('Heme A synthase COX15', 'Q7KZN9'),
#  ('Rho-related GTP-binding protein RhoU', 'Q7L0Q8'),
#  ('Cytochrome b5 reductase 4', 'Q7L1T6'),
#  ('Q7L2R6', 'Zinc finger protein 765'),
#  ('Protein MCM10 homolog', 'Q7L590'),
#  ('Q7L5L3', 'Lysophospholipase D GDPD3'),
#  ('Q7L5Y9', 'E3 ubiquitin-protein transferase MAEA'),
#  ('Q7L622', 'G2/M phase-specific E3 ubiquitin-protein ligase'),
#  ('Q7L9L4', 'MOB kinase activator 1B'),
#  ('Q7LBC6', 'Lysine-specific demethylase 3B'),
#  ('Ribonucleoside-diphosphate reductase subunit M2 B', 'Q7LG56'),
#  ('Q7RTP6', '[F-actin]-monooxygenase MICAL3'),
#  ('Q7RTZ1', 'Ovochymase-2'),
#  ('Aprataxin', 'Q7Z2E3'),
#  ('Endoplasmic reticulum metallopeptidase 1', 'Q7Z2K6'),
#  ('Q7Z2W4', 'Zinc finger CCCH-type antiviral protein 1'),
#  ('Q7Z2W7',
#   'Transient receptor potential cation channel subfamily M member 8'),
#  ('Protein mono-ADP-ribosyltransferase TIPARP', 'Q7Z3E1'),
#  ('Q7Z3I7', 'Zinc finger protein 572'),
#  ('Pogo transposable element with ZNF domain', 'Q7Z3K3'),
#  ('Q7Z3S7', 'Voltage-dependent calcium channel subunit alpha-2/delta-4'),
#  ('Zinc finger FYVE domain-containing protein 16', 'Q7Z3T8'),
#  ('Potassium channel subfamily K member 18', 'Q7Z418'),
#  ('Q7Z4I7', 'LIM and senescent cell antigen-like-containing domain protein 2'),
#  ('Inactive polypeptide N-acetylgalactosaminyltransferase-like protein 5',
#   'Q7Z4T8'),
#  ('Zinc finger protein 438', 'Q7Z4V0'),
#  ('Q7Z570', 'Zinc finger protein 804A'),
#  ('Q7Z5J4', 'Retinoic acid-induced protein 1'),
#  ('Q7Z5L9', 'Interferon regulatory factor 2-binding protein 2'),
#  ('E3 ubiquitin-protein ligase SH3RF1', 'Q7Z6J0'),
#  ('FYVE, RhoGEF and PH domain-containing protein 2', 'Q7Z6J4'),
#  ('THAP domain-containing protein 5', 'Q7Z6K1'),
#  ('Q7Z7K6', 'Centromere protein V'),
#  ('Q7Z7M9', 'Polypeptide N-acetylgalactosaminyltransferase 5'),
#  ('Polycomb group RING finger protein 5', 'Q86SE9'),
#  ('N-acetylgalactosaminyltransferase 7', 'Q86SF2'),
#  ('Q86SG6', 'Serine/threonine-protein kinase Nek8'),
#  ('Q86SK9', 'Stearoyl-CoA desaturase 5'),
#  ('Q86SQ9', 'Dehydrodolichyl diphosphate synthase complex subunit DHDDS'),
#  ('Q86SR1', 'Polypeptide N-acetylgalactosaminyltransferase 10'),
#  ('Glutaredoxin-related protein 5, mitochondrial', 'Q86SX6'),
#  ('Transcriptional regulator Kaiso', 'Q86T24'),
#  ('Q86T96', 'E3 ubiquitin-protein ligase RNF180'),
#  ('Q86TM6', 'E3 ubiquitin-protein ligase synoviolin'),
#  ('Q86TP1', 'Exopolyphosphatase PRUNE1'),
#  ('RPA-interacting protein', 'Q86UA6'),
#  ...]

# %% [markdown]
# ## How many proteins dont have any GO term?

# %%
def proteins_with_no_go_types(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)

    no_go_term_proteins = []

    # Iterate through the proteins in the data
    for protein in data:
        go_annotations = protein.get("go_annotations", [])
        if not go_annotations:
            protein_id = protein.get("protein_id")
            protein_name = protein.get("protein_name")
            
            no_go_term_proteins.append(tuple({protein_id, protein_name}))

    return no_go_term_proteins

def all_proteins(json_file):
    with open(json_file, 'r') as f:
        data = json.load(f)
        
    proteins = []
    
    for protein in data:
        protein_id = protein.get("protein_id")
        protein_name = protein.get("protein_name")
        proteins.append(tuple({protein_id, protein_name}))
        
    return proteins

# %%
no_go_proteins = proteins_with_no_go_types(json_file)
# print(no_go_proteins)
print(f"Number of proteins without go terms: {len(no_go_proteins)}")

all_prots = all_proteins(json_file)
print(f"Number of all proteins: {len(all_prots)}")
print(f"Percentage: {len(no_go_proteins) / len(all_prots)*100:.2f}%")
# Out:
# Number of proteins without go terms: 4339
# Number of all proteins: 20421
# Percentage: 21.25%

# %% [markdown]
# ## Analysis with complete hierarchie

# %%
json_file_with_hierarchie = "./../embeddings/compressed_protein_data.json" 
go_ids_to_proteins_complete = map_go_annotations_ids_only_to_proteins(json_file_with_hierarchie)

# %%
def add_name_to_go_id(ids_to_proteins, name_to_id_mapping):
    """
    Convert a dictionary mapping GO IDs to proteins into a dictionary mapping GO names to proteins.

    Parameters:
        ids_to_proteins (dict): A dictionary where keys are GO IDs and values are lists of proteins.
        name_to_id_mapping (dict): A dictionary mapping GO names to GO IDs.

    Returns:
        dict: A dictionary where keys are GO names and values are lists of proteins.
    """
    # Reverse the name-to-ID mapping to create an ID-to-name mapping
    id_to_name_mapping = {go_id: go_name for go_name, go_id in name_to_id_mapping.items()}

    # Create a new dictionary mapping GO names to proteins
    names_to_proteins = {}

    for go_id, proteins in ids_to_proteins.items():
        # Lookup the name for the GO ID
        go_name = id_to_name_mapping.get(go_id)
        if go_name:
            # Map the name to the proteins
            names_to_proteins[go_name] = proteins
        else:
            print(f"Warning: GO ID {go_id} not found in the GO name mapping.")

    return names_to_proteins

# %%
go_name_to_proteins_complete = add_name_to_go_id(go_ids_to_proteins_complete, name_to_id)
analyze_go_distribution_large(go_name_to_proteins_complete, top_n=10)

# %% [markdown]
# ## Log plots

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter

def analyze_go_distribution_log_large(go_to_proteins, top_n=100, use_log_scale=True):
    """
    Analyzes and visualizes the distribution of GO terms.

    Parameters:
        go_to_proteins (dict): A dictionary mapping GO terms to protein IDs.
        top_n (int): Number of top GO terms to display in the plot. Default is 20.
        use_log_scale (bool): Whether to use a logarithmic scale for the x-axis.
    """
    # Count the occurrences of each GO term
    go_counts = {go: len(proteins) for go, proteins in go_to_proteins.items()}

    # Sort and select the top N GO terms
    top_go_counts = dict(Counter(go_counts).most_common(top_n))

    # Dynamically adjust figure size based on the number of terms
    height_per_bar = 0.5
    total_height = height_per_bar * len(top_go_counts)
    plt.figure(figsize=(12, max(8, total_height)))

    # Apply log transformation if enabled
    frequencies = list(top_go_counts.values())
    if use_log_scale:
        frequencies = [np.log10(freq + 1) for freq in frequencies]  # Avoid log(0) by adding 1

    # Plot the distribution
    plt.barh(list(top_go_counts.keys()), frequencies, color='skyblue')
    plt.xlabel('Log(Frequency + 1)' if use_log_scale else 'Frequency (Number of Proteins)')
    plt.ylabel('GO Terms')
    plt.title(f'Top {top_n} GO Terms Distribution')
    plt.gca().invert_yaxis()  # Invert y-axis to show the most frequent GO term at the top
    plt.tight_layout()
    plt.show()

# %%
analyze_go_distribution_log_large(go_name_to_proteins_complete, top_n=100)
