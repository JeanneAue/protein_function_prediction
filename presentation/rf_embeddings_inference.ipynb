# %% [markdown]
# # From Sequence to prediction

# %%
from transformers import BertTokenizer, BertModel
import torch 
import numpy as np
import json
import sys

import joblib
import warnings

from sklearn.exceptions import InconsistentVersionWarning

warnings.filterwarnings("ignore", category=InconsistentVersionWarning)

# %%
np.set_printoptions(threshold=sys.maxsize, suppress=True)
tokenizer = BertTokenizer.from_pretrained("Rostlab/prot_bert", do_lower_case=False)
model = BertModel.from_pretrained("Rostlab/prot_bert")

# %% [markdown]
# Now we are loading the classifier:

# %%
classifier = joblib.load("./../models/protein_function_classifier_rf.pkl")
mlb = joblib.load("./../models/go_mlb_rf.pkl")

# %%
def generate_embedding(sequence):
    spaced_sequence = " ".join(sequence)

    inputs = tokenizer(spaced_sequence, return_tensors="pt", padding=True)
    with torch.no_grad():
        outputs = model(**inputs)

    embeddings = outputs.last_hidden_state.mean(dim=1).squeeze(0).numpy()
    return embeddings

# %%
def get_sequence_by_id(protein_id, json_file):
    try:
        with open(json_file, 'r') as file:
            data = json.load(file)
            for protein in data:
                if protein['protein_id'] == protein_id:
                    return protein['sequence']
            return f"Protein ID {protein_id} not found in the JSON file."
    except FileNotFoundError:
        return f"The file {json_file} does not exist."
    except json.JSONDecodeError:
        return f"The file {json_file} is not a valid JSON file."

# %% [markdown]
# Please provide your Protein ID here:

# %%
protein_id = "A0A087X1C5"
json_file = "./../raw_data/filtered_proteins.json"
example_sequence = get_sequence_by_id(protein_id, json_file)

print("Generating embeddings for the example sequence...")
embedding = generate_embedding(example_sequence)
# Out:
# Generating embeddings for the example sequence...

# %% [markdown]
# Now the embedding is created and we need to perform the inference query to get a protein function prediction:

# %%
new_protein_embedding = np.array(embedding).reshape(1, -1)

predicted_labels = classifier.predict(new_protein_embedding)

predicted_go_terms = mlb.inverse_transform(predicted_labels)
print(f"Predicted GO terms: {predicted_go_terms}")
# Out:
# Predicted GO terms: [('GO:0003674', 'GO:0003723', 'GO:0005102', 'GO:0005515', 'GO:0008092', 'GO:0008270', 'GO:0008324', 'GO:0015075', 'GO:0015631', 'GO:0016787', 'GO:0019899', 'GO:0019904', 'GO:0022857', 'GO:0030234', 'GO:0030545', 'GO:0030546', 'GO:0032555', 'GO:0042803', 'GO:0044877', 'GO:0046872', 'GO:0046914', 'GO:0046982', 'GO:0048018', 'GO:0060090', 'GO:0097159', 'GO:0097367', 'GO:0098772', 'GO:0140096', 'GO:0140677', 'GO:0140678', 'GO:1901363')]

# %% [markdown]
# If you want to see the embeddings, execute the following block

# %%
print("Embeddings: ")
print(embedding)
# Out:
# Embeddings:
# [ 0.01051687 -0.01371659 -0.08702055 -0.27543494  0.12567727 -0.07036006
#  -0.04007847 -0.1526646  -0.0478871  -0.00317483  0.03922058  0.02364367
#  -0.01420561  0.0004388   0.04825511 -0.04509901 -0.0141239   0.07379692
#  -0.03288254 -0.09540947  0.01661189  0.07377736  0.02280229 -0.05433457
#   0.16710903  0.02190277 -0.0481483   0.02541325  0.0663678  -0.03579415
#  -0.16128212 -0.01293594 -0.01012319 -0.00787872  0.10964928 -0.01035678
#   0.08901549  0.07282551 -0.03726026 -0.10245537  0.08092152  0.07985996
#   0.08264763  0.06841749  0.06869935 -0.1824903   0.09051856 -0.09394525
#   0.06872425  0.05473294  0.07810044 -0.04663794 -0.04541186 -0.03445394
#   0.07969369 -0.03707615  0.03900292 -0.19981618  0.01975638 -0.0442605
#  -0.01295741 -0.02251619  0.04137708 -0.03254373 -0.09185991 -0.02661838
#  -0.05136071 -0.00914741  0.10501354 -0.10021848 -0.14759791  0.07029811
#  -0.05987056  0.00496947  0.05662007  0.07041849 -0.09743576  0.04797089
#  -0.00505347 -0.03980897 -0.01533495  0.18360907 -0.00072274 -0.00424491
#   0.0531365  -0.11684158 -0.05235072  0.08120143  0.26522034 -0.03358459
#  -0.02031224 -0.13055773  0.04051381 -0.05744595  0.04877659  0.14564323
#   0.27900618  0.030736    0.11038062  0.00399886 -0.05820148  0.07637724
#  -0.01346589 -0.00204453 -0.01380108 -0.20441903  0.04412163  0.05287262
#   0.06888571  0.12316459 -0.06955133 -0.01581122  0.05440414 -0.05511517
#  -0.02676499  0.09136766  0.0303203   0.16459419  0.06530556 -0.18618111
#   0.01908765  0.07957704 -0.0330894   0.00148118  0.0589778   0.14404128
#   0.12289505 -0.03305057 -0.18246607  0.10410849 -0.11094192 -0.05813191
#   0.08148143  0.01471723 -0.01381024  0.04016388  0.0420001   0.05706767
#  -0.0806437  -0.04237783  0.0197926   0.06581566 -0.04859529 -0.07787222
#  -0.01754689  0.27063403 -0.14985736  0.09963161 -0.0482944   0.04351861
#   0.01898094  0.07016823  0.03342235 -0.06024712  0.03654392 -0.0686912
#  -0.08168342 -0.07959665 -0.11937059 -0.00285884 -0.1239206   0.12377045
#   0.08305443 -0.06580956  0.00682484 -0.03278395 -0.07928084  0.03811069
#  -0.00660322 -0.01368015 -0.21573764  0.11583699 -0.06033013  0.02395768
#  -0.00775389  0.04317672 -0.09879664 -0.22060703  0.03730022 -0.10808244
#  -0.028672   -0.12998007  0.05815592 -0.04968012  0.01718996  0.05087847
#  -0.09179617  0.04126152 -0.04688269  0.03015034 -0.03144498 -0.04926699
#  -0.01481438  0.06209686  0.10335034  0.0204893   0.18358487  0.12459923
#  -0.03251044 -0.03220382 -0.09404323  0.11535694  0.10520105 -0.08148341
#   0.09590977 -0.08889952 -0.1383892   0.11470127 -0.14988163 -0.01377379
#  -0.12714918  0.03197537 -0.1573816  -0.00510076 -0.1360205   0.03344079
#   0.04302539  0.14997528 -0.07734682  0.04516528  0.3027353  -0.03995289
#  -0.03096267 -0.06349313 -0.19008845  0.20646624  0.08089571  0.12166499
#  -0.01987976  0.04793471  0.01355683 -0.10910246  0.00399445 -0.0917603
#  -0.06648669  0.04632542 -0.3181178  -0.03352782 -0.0694818  -0.06893082
#   0.03501479 -0.00396172  0.11093692 -0.03292176  0.15345167  0.00783768
#  -0.07359213  0.07769723  0.10508128 -0.00975741  0.04177976 -0.02158884
#  -0.01983557  0.19245715  0.02484255  0.052429   -0.03255346 -0.12467723
#   0.03028967 -0.02132398 -0.0154478  -0.09316383 -0.0189833   0.10829568
#   0.10498981  0.02477933 -0.02442733  0.03844253  0.12143873 -0.31523705
#  -0.11847876  0.04352522  0.00913181  0.02013074 -0.01624318  0.07544225
#  -0.19186917 -0.07841895 -0.00028414  0.09275188 -0.08609006 -0.11973093
#   0.01207672 -0.0479862   0.09262235  0.1338959  -0.0303359   0.00734126
#   0.07476807  0.14664447  0.13194594  0.25795668  0.12495227  0.14628264
#  -0.07584114  0.03109353  0.27583224  0.04153527 -0.10469805 -0.16401498
#  -0.1253547  -0.05760272  0.07256018  0.06722073 -0.27702844 -0.01334085
#  -0.11157043  0.04535356 -0.08078734  0.04502729  0.01527176 -0.05168625
#  -0.07572152  0.15238243 -0.15918767  0.04584005 -0.1313949  -0.08189702
#  -0.00170263 -0.0143935  -0.02774807 -0.05289666  0.00161072 -0.16939816
#  -0.07096249 -0.03871445  0.00874502 -0.08244792  0.3635419  -0.0298906
#  -0.0493928   0.00156353 -0.0014125  -0.01813293 -0.15802817  0.12177835
#   0.11000133 -0.08416541  0.1386651  -0.08232348  0.06583332  0.05921619
#   0.10662738  0.08155144 -0.01731078  0.04268009 -0.07359895  0.18107495
#   0.11797635  0.08101933 -0.01610662 -0.17923543 -0.01146092 -0.05767743
#  -0.1556736  -0.01317514 -0.06781311  0.08349092 -0.18410824 -0.07805714
#   0.02318814 -0.08085237 -0.01046426  0.1269013  -0.00381919 -0.0363102
#   0.05980553  0.03870995 -0.05235223 -0.17135292  0.21435998  0.04867022
#   0.01577944 -0.08736357 -0.1115586   0.0302806  -0.04365467  0.03557007
#   0.07546931  0.08143416 -0.02958753  0.09275858 -0.02362084 -0.10497715
#   0.02274279 -0.17287461  0.0529277  -0.1553477  -0.02114215  0.02651473
#   0.086318   -0.03029742 -0.05962007  0.10613772 -0.01171197  0.13610332
#  -0.06907139  0.10918429  0.08795045 -0.0352728  -0.15034723  0.09117451
#  -0.13092373  0.0383267  -0.12685813 -0.16667071 -0.0042773  -0.19596623
#   0.1468805  -0.14909518  0.16097064  0.09800951 -0.04852368 -0.07181498
#  -0.0668255  -0.13750729  0.05099598 -0.03401073 -0.02878033 -0.12163999
#  -0.01804771  0.02155085 -0.14415331 -0.00437782 -0.17168915  0.05168108
#  -0.00134275  0.02176327  0.16024114  0.13675195  0.08263421  0.0773581
#   0.03931767  0.12672561 -0.18446338 -0.36053148 -0.09607743 -0.19279703
#  -0.07394652  0.10753191 -0.02135235 -0.00612345  0.02760312  0.06382728
#   0.07414076 -0.04485363  0.06190332  0.0720434   0.11078756  0.07869088
#   0.0541613  -0.06609847  0.05289359  0.10736437  0.09212288  0.04559434
#   0.15349339 -0.08781344 -0.12143992 -0.00425536  0.01264078  0.1027353
#   0.17295897  0.02109241  0.04348749 -0.1446127  -0.00471479 -0.11680868
#  -0.00985581  0.02096081  0.04816404 -0.00351829 -0.14455433  0.10098711
#  -0.04848443  0.10916417  0.12195304 -0.15488595  0.2061451   0.14438824
#   0.011738   -0.08064511 -0.02286236 -0.10981018  0.03648246 -0.06498316
#   0.15109128 -0.03125972  0.12272617 -0.10883034 -0.08397808  0.12308165
#  -0.13344103 -0.0304472   0.17601772  0.09009665  0.00702284  0.02348723
#  -0.13436557  0.03432447  0.02441738  0.05696057 -0.08883969 -0.12020925
#  -0.04591799 -0.05170736 -0.03087183  0.00726424  0.03833484  0.01082802
#   0.01421152 -0.01053182 -0.01657907 -0.03434037  0.04536039 -0.09785609
#   0.15910052  0.03390704  0.10357465 -0.04091287 -0.01044711 -0.01413408
#  -0.05983537 -0.1667086   0.16551974  0.09393295  0.07951792  0.06778615
#  -0.05154668 -0.00305532 -0.08516477  0.01423595  0.05671379 -0.01902992
#   0.14876464 -0.03245072 -0.02266648  0.10151194  0.11087053  0.07834662
#   0.12151767  0.01832141 -0.12363702  0.08098613 -0.03065971  0.10600846
#   0.04920822 -0.10788184 -0.00439153  0.03182046  0.07542865  0.11010346
#   0.03978249 -0.07699793  0.07883798  0.08756787  0.01859029  0.00173336
#   0.18661389 -0.16220939 -0.3004144   0.02858719 -0.17278959  0.02217975
#   0.00981761 -0.12752871  0.16044904  0.00112444 -0.0009908   0.06729256
#  -0.01239937  0.00738293 -0.06268651 -0.04365359 -0.08012412  0.02681424
#   0.05778198  0.0131936   0.10737486  0.14180511  0.06619313  0.1558495
#   0.07696747 -0.02408026  0.07275874 -0.10775845 -0.02260024 -0.1607647
#   0.00137517 -0.00751131 -0.06344496 -0.05705714  0.01788623  0.10286475
#   0.0336471  -0.14300583  0.00446107 -0.23174466 -0.07843702 -0.07727931
#   0.0378026   0.04993207  0.06617355 -0.17237349 -0.04809891  0.02696195
#   0.04061181 -0.04121611 -0.08194111 -0.00795105 -0.0474491   0.02906027
#   0.20263149 -0.02954059  0.05640406 -0.08840439 -0.15660056  0.00826477
#  -0.17153367  0.00792057  0.08586521  0.05194503  0.01120785 -0.08069243
#  -0.06400339  0.01964542 -0.15273339  0.02722095  0.00755554  0.00437433
#  -0.05443867 -0.11241882  0.09078884  0.07047408  0.12868765  0.08848129
#   0.12880711 -0.08431853  0.04071442  0.00368088 -0.02370144 -0.04430816
#   0.02725253  0.01606709 -0.01488607 -0.01189922  0.0786743  -0.01925709
#  -0.17337278  0.07210216  0.08036993 -0.1496653  -0.00722975  0.04530851
#  -0.08511583 -0.13135575 -0.02635306  0.00091801  0.05131726  0.06335562
#   0.0131754   0.03324612 -0.06494878 -0.16179352 -0.06205848  0.11438502
#   0.08554074  0.04481907 -0.11905491  0.0126412   0.00620281  0.13540183
#  -0.09817519  0.00587006  0.00672226  0.0841658   0.11544831  0.1677918
#  -0.13868007  0.02385959  0.05338197  0.04015055  0.07353121 -0.0241596
#   0.24729453 -0.12023303  0.15942225 -0.05475787 -0.02839757 -0.05764432
#  -0.1478181  -0.04978127  0.00959205  0.0799261   0.1509589  -0.05809492
#  -0.01770995 -0.00684409 -0.0095194  -0.0076797  -0.04907767 -0.04617004
#   0.04376706 -0.01217187 -0.13600442 -0.09978618  0.0332255   0.02471786
#  -0.00187496  0.16789848 -0.15007962  0.0038251   0.0146339  -0.02803086
#  -0.05171455 -0.21803385 -0.3871818   0.07105546  0.03865564 -0.04360125
#   0.08071379  0.12060029 -0.04822928 -0.03968124  0.07810339  0.09963082
#  -0.00665178  0.00512894 -0.05956252 -0.06135682 -0.12244099  0.07664457
#   0.14227937 -0.07044711 -0.17155764 -0.05570472 -0.06834615  0.20183855
#   0.1361882  -0.12871693  0.13589646  0.0365158   0.15149756  0.01911378
#  -0.10995105 -0.08522939 -0.13498645  0.07555541 -0.0187608   0.06353825
#  -0.01934722 -0.06609047 -0.01843092  0.03672685 -0.1915873  -0.00467397
#  -0.08685827 -0.05525903 -0.10253839  0.13362761 -0.06323592 -0.02686121
#  -0.00145914  0.27557078  0.08751813  0.0025801  -0.00657648  0.01030409
#  -0.07483163  3.4781928  -0.07080191  0.19261827 -0.04596092  0.00211748
#  -0.12556198  0.03783875 -0.03880521  0.13200325 -0.0786546   0.02296473
#   0.18349577  0.14195043 -0.08614034  0.03827662  0.13015704  0.02390327
#   0.04511802  0.07413758  0.14706674  0.5475204   0.04745348  0.00668864
#   0.04488007 -0.23668416 -0.12991285 -0.01421343 -0.14235376  0.12912516
#   0.13156697 -0.2646358  -0.08399469  0.11116671 -0.22039798 -0.11140594
#  -0.11378339  0.03395757  0.03447776  0.10037595 -0.02624641  0.0546854
#  -0.04390318  0.03770205  0.03729406  0.05799662  0.14948109 -0.33104888
#  -0.01351896 -0.05790165  0.13948856 -0.05775074 -0.07163399 -0.02514406
#   0.22719727  0.30337214 -0.96991    -0.05250755 -0.10446627 -0.23406719
#   0.01085009  0.02829466 -0.13166866  0.11079899  0.17193672 -0.05128941
#   0.06238388 -0.05740352  0.04257379  0.21765603 -0.03838624 -0.07067893
#  -0.18688571  0.0111677   0.01501907  0.0789807   0.20105132 -0.06097625
#  -0.13380526 -0.06986713  0.02060171  0.10645964 -0.02663163 -0.0052922
#  -0.06369546 -0.04145262  0.00955252  0.13023485 -0.23749848 -0.03123228
#   0.0270785   0.01618336  0.06371866  0.0629627   0.04227943  0.00771228
#   0.06852291  0.01003941  0.07056563  0.01602297 -0.08669079 -0.21293148
#  -0.04578691 -0.10027409  0.04809671 -0.0578409   0.08737378  0.16199146
#   0.08423974 -0.10908016  0.07154054 -0.04813854 -0.05411039 -0.12615055
#   0.08984865  0.1649476   0.16385414  0.02933276  0.1220265   0.1152744
#  -0.00522072  0.06538825  0.04493276  0.00907105  0.09271727 -0.04742911
#  -0.04731467  0.02114443 -0.08084058 -0.08670104  0.057387    0.09316292
#  -0.05064425 -0.02921338 -0.06710003 -0.1041018   0.02945204  0.0625511
#  -0.06186436 -0.01936947 -0.05765877  0.00818888  0.11297936 -0.01524279
#   0.02079673 -0.00324637 -0.1086707   0.1350254  -0.11971813 -0.03878066
#  -0.0898892   0.02292644 -0.02893437  0.04619934  0.09811696 -0.02943931
#  -0.00270569  0.16561158  0.07396276  0.06597415  0.06368379  0.01797004
#  -0.06670005 -0.04561216  0.06274533  0.15422086 -0.03864853  0.00669613
#  -0.03706185 -0.07215228 -0.06417773  0.01030496 -0.08508094 -0.01969551
#  -0.19139574  0.03628154 -0.03052364 -0.08312707 -0.01977895  0.10295747
#   0.0531958  -0.09129804 -0.00142681 -0.10171337 -0.23411213  0.16085508
#   0.00617236  0.0125436  -0.07258039 -0.01696585  0.02263928 -0.09203964
#  -0.06394877 -0.06597774  0.00033934 -0.19627395  0.02585547  0.04089947
#  -0.12996815 -0.09852892 -0.04587889  0.12015317 -0.04799467 -0.0891196
#  -0.15598604  0.08510937  0.14106698  0.05298994  0.06400742 -0.05094074
#  -0.08126916 -0.02460332  0.02131235  0.13905638 -0.12949228  0.04646783
#   0.24325222  0.03891021  0.04383491 -0.00184444  0.07859445 -0.13050717
#  -0.04061822  0.03621216  0.02311008 -0.24016355 -0.04360757 -0.07869324
#   0.05202539  0.02609723 -0.04163992  0.07177215  0.03776819 -0.0847428
#  -0.01933051 -0.07588425  0.05527487 -0.18198699 -0.06146058  0.04016242
#  -0.04525472  0.00230709 -0.05290819  0.02137309 -0.01133507  0.21456032
#   0.04528126 -0.09277741  0.03700694 -0.10775643  0.04213778  0.0096137
#  -0.12274443  0.04133597 -0.03864764  0.00067453]
